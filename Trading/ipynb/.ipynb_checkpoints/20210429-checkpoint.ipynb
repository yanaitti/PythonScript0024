# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('inputs/USDJPY_M15.csv', sep='\t', names=('date', 'time', 'open', 'high', 'low', 'close'), usecols=[0, 1, 2, 3, 4, 5], skiprows=1)
data['datetime'] = pd.to_datetime(data['date']  + ' ' + data['time'])
data.drop(['date', 'time'], axis=1, inplace=True)
data
# Out:
#           open     high      low    close            datetime
# 0      107.513  107.754  107.502  107.646 2020-03-02 00:00:00
# 1      107.646  107.769  107.629  107.717 2020-03-02 00:15:00
# 2      107.717  107.731  107.635  107.640 2020-03-02 00:30:00
# 3      107.641  107.646  107.362  107.375 2020-03-02 00:45:00
# 4      107.375  107.591  107.361  107.498 2020-03-02 01:00:00
# ...        ...      ...      ...      ...                 ...
# 28335  107.877  107.895  107.863  107.893 2021-04-23 22:45:00
# 28336  107.892  107.902  107.886  107.900 2021-04-23 23:00:00
# 28337  107.903  107.904  107.885  107.887 2021-04-23 23:15:00
# 28338  107.886  107.908  107.884  107.888 2021-04-23 23:30:00
# 28339  107.888  107.903  107.868  107.875 2021-04-23 23:45:00
#
# [28340 rows x 5 columns]

# %%
# all_data = pd.merge(data, ni225, on='datetime', suffixes=['', '_ni225']).drop(['date_ni225', 'time_ni225'], axis=1)
all_data = data.copy()
all_data
# Out:
#           open     high      low    close            datetime
# 0      107.513  107.754  107.502  107.646 2020-03-02 00:00:00
# 1      107.646  107.769  107.629  107.717 2020-03-02 00:15:00
# 2      107.717  107.731  107.635  107.640 2020-03-02 00:30:00
# 3      107.641  107.646  107.362  107.375 2020-03-02 00:45:00
# 4      107.375  107.591  107.361  107.498 2020-03-02 01:00:00
# ...        ...      ...      ...      ...                 ...
# 28335  107.877  107.895  107.863  107.893 2021-04-23 22:45:00
# 28336  107.892  107.902  107.886  107.900 2021-04-23 23:00:00
# 28337  107.903  107.904  107.885  107.887 2021-04-23 23:15:00
# 28338  107.886  107.908  107.884  107.888 2021-04-23 23:30:00
# 28339  107.888  107.903  107.868  107.875 2021-04-23 23:45:00
#
# [28340 rows x 5 columns]

# %%
# extract features from date
all_data['day'] = [i.day for i in all_data['datetime']]
all_data['month'] = [i.month for i in all_data['datetime']]
all_data['year'] = [i.year for i in all_data['datetime']]
all_data['day_of_week'] = [i.dayofweek for i in all_data['datetime']]
all_data['day_of_year'] = [i.dayofyear for i in all_data['datetime']]

all_data['hour'] = [i.hour for i in all_data['datetime']]
all_data['minute'] = [i.minute for i in all_data['datetime']]

all_data
# Out:
#           open     high      low    close            datetime  day  month  \
# 0      107.513  107.754  107.502  107.646 2020-03-02 00:00:00    2      3
# 1      107.646  107.769  107.629  107.717 2020-03-02 00:15:00    2      3
# 2      107.717  107.731  107.635  107.640 2020-03-02 00:30:00    2      3
# 3      107.641  107.646  107.362  107.375 2020-03-02 00:45:00    2      3
# 4      107.375  107.591  107.361  107.498 2020-03-02 01:00:00    2      3
# ...        ...      ...      ...      ...                 ...  ...    ...
# 28335  107.877  107.895  107.863  107.893 2021-04-23 22:45:00   23      4
# 28336  107.892  107.902  107.886  107.900 2021-04-23 23:00:00   23      4
# 28337  107.903  107.904  107.885  107.887 2021-04-23 23:15:00   23      4
# 28338  107.886  107.908  107.884  107.888 2021-04-23 23:30:00   23      4
# 28339  107.888  107.903  107.868  107.875 2021-04-23 23:45:00   23      4
#
#        year  day_of_week  day_of_year  hour  minute
# 0      2020            0           62     0       0
# 1      2020            0           62     0      15
# 2      2020            0           62     0      30
# 3      2020            0           62     0      45
# 4      2020            0           62     1       0
# ...     ...          ...          ...   ...     ...
# 28335  2021            4          113    22      45
# 28336  2021            4          113    23       0
# 28337  2021            4          113    23      15
# 28338  2021            4          113    23      30
# 28339  2021            4          113    23      45
#
# [28340 rows x 12 columns]

# %%
# dataset = all_data[['open', 'high', 'low', 'close', 'tickvol', 'day', 'month', 'year', 'day_of_week', 'day_of_year', 'hour', 'minute', 'open_ni225', 'high_ni225', 'low_ni225', 'close_ni225', 'tickvol_ni225']]
dataset = all_data[['open', 'high', 'low', 'close', 'day', 'month', 'year', 'day_of_week', 'day_of_year', 'hour', 'minute']]
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 0      107.513  107.754  107.502  107.646    2      3  2020            0
# 1      107.646  107.769  107.629  107.717    2      3  2020            0
# 2      107.717  107.731  107.635  107.640    2      3  2020            0
# 3      107.641  107.646  107.362  107.375    2      3  2020            0
# 4      107.375  107.591  107.361  107.498    2      3  2020            0
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 28335  107.877  107.895  107.863  107.893   23      4  2021            4
# 28336  107.892  107.902  107.886  107.900   23      4  2021            4
# 28337  107.903  107.904  107.885  107.887   23      4  2021            4
# 28338  107.886  107.908  107.884  107.888   23      4  2021            4
# 28339  107.888  107.903  107.868  107.875   23      4  2021            4
#
#        day_of_year  hour  minute
# 0               62     0       0
# 1               62     0      15
# 2               62     0      30
# 3               62     0      45
# 4               62     1       0
# ...            ...   ...     ...
# 28335          113    22      45
# 28336          113    23       0
# 28337          113    23      15
# 28338          113    23      30
# 28339          113    23      45
#
# [28340 rows x 11 columns]

# %%
dataset['y'] = dataset['high'].shift(-1)

# %%
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 0      107.513  107.754  107.502  107.646    2      3  2020            0
# 1      107.646  107.769  107.629  107.717    2      3  2020            0
# 2      107.717  107.731  107.635  107.640    2      3  2020            0
# 3      107.641  107.646  107.362  107.375    2      3  2020            0
# 4      107.375  107.591  107.361  107.498    2      3  2020            0
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 28335  107.877  107.895  107.863  107.893   23      4  2021            4
# 28336  107.892  107.902  107.886  107.900   23      4  2021            4
# 28337  107.903  107.904  107.885  107.887   23      4  2021            4
# 28338  107.886  107.908  107.884  107.888   23      4  2021            4
# 28339  107.888  107.903  107.868  107.875   23      4  2021            4
#
#        day_of_year  hour  minute        y
# 0               62     0       0  107.769
# 1               62     0      15  107.731
# 2               62     0      30  107.646
# 3               62     0      45  107.591
# 4               62     1       0  107.700
# ...            ...   ...     ...      ...
# 28335          113    22      45  107.902
# 28336          113    23       0  107.904
# 28337          113    23      15  107.908
# 28338          113    23      30  107.903
# 28339          113    23      45      NaN
#
# [28340 rows x 12 columns]

# %%
for i in range(1, 13):
    dataset['shift%s'%i] = dataset['open'].shift(i)

dataset['sma5'] = dataset['open'].rolling(5).mean()
dataset['sma15'] = dataset['open'].rolling(15).mean()
# dataset['sma50'] = dataset['open'].rolling(50).mean()
# dataset['sma100'] = dataset['open'].rolling(100).mean()
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 0      107.513  107.754  107.502  107.646    2      3  2020            0
# 1      107.646  107.769  107.629  107.717    2      3  2020            0
# 2      107.717  107.731  107.635  107.640    2      3  2020            0
# 3      107.641  107.646  107.362  107.375    2      3  2020            0
# 4      107.375  107.591  107.361  107.498    2      3  2020            0
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 28335  107.877  107.895  107.863  107.893   23      4  2021            4
# 28336  107.892  107.902  107.886  107.900   23      4  2021            4
# 28337  107.903  107.904  107.885  107.887   23      4  2021            4
# 28338  107.886  107.908  107.884  107.888   23      4  2021            4
# 28339  107.888  107.903  107.868  107.875   23      4  2021            4
#
#        day_of_year  hour  ...   shift5   shift6   shift7   shift8   shift9  \
# 0               62     0  ...      NaN      NaN      NaN      NaN      NaN
# 1               62     0  ...      NaN      NaN      NaN      NaN      NaN
# 2               62     0  ...      NaN      NaN      NaN      NaN      NaN
# 3               62     0  ...      NaN      NaN      NaN      NaN      NaN
# 4               62     1  ...      NaN      NaN      NaN      NaN      NaN
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 28335          113    22  ...  107.934  107.958  107.944  107.952  107.944
# 28336          113    23  ...  107.927  107.934  107.958  107.944  107.952
# 28337          113    23  ...  107.927  107.927  107.934  107.958  107.944
# 28338          113    23  ...  107.933  107.927  107.927  107.934  107.958
# 28339          113    23  ...  107.909  107.933  107.927  107.927  107.934
#
#        shift10  shift11  shift12      sma5       sma15
# 0          NaN      NaN      NaN       NaN         NaN
# 1          NaN      NaN      NaN       NaN         NaN
# 2          NaN      NaN      NaN       NaN         NaN
# 3          NaN      NaN      NaN       NaN         NaN
# 4          NaN      NaN      NaN  107.5784         NaN
# ...        ...      ...      ...       ...         ...
# 28335  107.947  107.975  107.968  107.9146  107.940133
# 28336  107.944  107.947  107.975  107.9076  107.937000
# 28337  107.952  107.944  107.947  107.9028  107.932667
# 28338  107.944  107.952  107.944  107.8934  107.927200
# 28339  107.958  107.944  107.952  107.8892  107.921400
#
# [28340 rows x 26 columns]

# %%
dataset = dataset[100:-1]
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 100    108.263  108.364  108.236  108.237    3      3  2020            1
# 101    108.236  108.273  108.206  108.232    3      3  2020            1
# 102    108.232  108.320  108.216  108.315    3      3  2020            1
# 103    108.315  108.532  108.315  108.522    3      3  2020            1
# 104    108.522  108.522  108.350  108.368    3      3  2020            1
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 28334  107.909  107.915  107.860  107.878   23      4  2021            4
# 28335  107.877  107.895  107.863  107.893   23      4  2021            4
# 28336  107.892  107.902  107.886  107.900   23      4  2021            4
# 28337  107.903  107.904  107.885  107.887   23      4  2021            4
# 28338  107.886  107.908  107.884  107.888   23      4  2021            4
#
#        day_of_year  hour  ...   shift5   shift6   shift7   shift8   shift9  \
# 100             63     1  ...  108.332  108.309  108.321  108.432  108.135
# 101             63     1  ...  108.336  108.332  108.309  108.321  108.432
# 102             63     1  ...  108.312  108.336  108.332  108.309  108.321
# 103             63     1  ...  108.302  108.312  108.336  108.332  108.309
# 104             63     2  ...  108.305  108.302  108.312  108.336  108.332
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 28334          113    22  ...  107.958  107.944  107.952  107.944  107.947
# 28335          113    22  ...  107.934  107.958  107.944  107.952  107.944
# 28336          113    23  ...  107.927  107.934  107.958  107.944  107.952
# 28337          113    23  ...  107.927  107.927  107.934  107.958  107.944
# 28338          113    23  ...  107.933  107.927  107.927  107.934  107.958
#
#        shift10  shift11  shift12      sma5       sma15
# 100    108.022  107.966  107.851  108.3036  108.172733
# 101    108.135  108.022  107.966  108.2836  108.195667
# 102    108.432  108.135  108.022  108.2676  108.223600
# 103    108.321  108.432  108.135  108.2702  108.254533
# 104    108.309  108.321  108.432  108.3136  108.291600
# ...        ...      ...      ...       ...         ...
# 28334  107.975  107.968  107.968  107.9260  107.944867
# 28335  107.947  107.975  107.968  107.9146  107.940133
# 28336  107.944  107.947  107.975  107.9076  107.937000
# 28337  107.952  107.944  107.947  107.9028  107.932667
# 28338  107.944  107.952  107.944  107.8934  107.927200
#
# [28239 rows x 26 columns]

# %%
dataset.isnull().any()
# Out:
# open           False
# high           False
# low            False
# close          False
# day            False
# month          False
# year           False
# day_of_week    False
# day_of_year    False
# hour           False
# minute         False
# y              False
# shift1         False
# shift2         False
# shift3         False
# shift4         False
# shift5         False
# shift6         False
# shift7         False
# shift8         False
# shift9         False
# shift10        False
# shift11        False
# shift12        False
# sma5           False
# sma15          False
# dtype: bool

# %%
X = dataset.drop(['y'], axis=1)
y =  dataset['y']

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_val, y_val, reference=lgb_train)

# %%
# LightGBM parameters
params = {
        'task' : 'train',
        'boosting':'gbdt',
        'objective' : 'regression',
        'metric' : {'mape'},
        'num_leaves':78,
        'drop_rate':0.05,
        'learning_rate':0.005,
        'seed':0,
        'verbose':0,
        'device': 'cpu',
        'max_depth': -1, 
        'random_state': 0
}

# %%
evaluation_results = {}
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=100000,
                valid_sets=[lgb_train, lgb_eval],
                valid_names=['Train', 'Valid'],
                evals_result=evaluation_results,
                early_stopping_rounds=1000,
                verbose_eval=100)
# Out:
# [LightGBM] [Warning] seed is set=0, random_state=0 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=0, random_state=0 will be ignored. Current value: seed=0
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004691 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] seed is set=0, random_state=0 will be ignored. Current value: seed=0
# Training until validation scores don't improve for 1000 rounds
# [100]	Train's mape: 0.00495872	Valid's mape: 0.00863989
# [200]	Train's mape: 0.0030168	Valid's mape: 0.00529754
# [300]	Train's mape: 0.00184576	Valid's mape: 0.00326838
# [400]	Train's mape: 0.00114379	Valid's mape: 0.00203481
# [500]	Train's mape: 0.000728328	Valid's mape: 0.00129156
# [600]	Train's mape: 0.000490657	Valid's mape: 0.000846328
# [700]	Train's mape: 0.000360716	Valid's mape: 0.000582554
# [800]	Train's mape: 0.000294758	Valid's mape: 0.000437717
# [900]	Train's mape: 0.000263349	Valid's mape: 0.000362088
# [1000]	Train's mape: 0.000247692	Valid's mape: 0.000323043
# [1100]	Train's mape: 0.00023872	Valid's mape: 0.00030244
# [1200]	Train's mape: 0.000232501	Valid's mape: 0.000291337
# [1300]	Train's mape: 0.000227602	Valid's mape: 0.000285591
# [1400]	Train's mape: 0.000223347	Valid's mape: 0.000281599
# [1500]	Train's mape: 0.00021946	Valid's mape: 0.000279976
# [1600]	Train's mape: 0.000215572	Valid's mape: 0.000278849
# [1700]	Train's mape: 0.000212353	Valid's mape: 0.000278135
# [1800]	Train's mape: 0.000209403	Valid's mape: 0.000277869
# [1900]	Train's mape: 0.000206771	Valid's mape: 0.000278766
# [2000]	Train's mape: 0.000204306	Valid's mape: 0.000279819
# [2100]	Train's mape: 0.000202039	Valid's mape: 0.000281234
# [2200]	Train's mape: 0.000199835	Valid's mape: 0.000281926
# [2300]	Train's mape: 0.000197756	Valid's mape: 0.000283281
# [2400]	Train's mape: 0.000195692	Valid's mape: 0.000284287
# [2500]	Train's mape: 0.000193743	Valid's mape: 0.000285335
# [2600]	Train's mape: 0.000191822	Valid's mape: 0.000286313
# [2700]	Train's mape: 0.000189992	Valid's mape: 0.000287362
# Early stopping, best iteration is:
# [1757]	Train's mape: 0.000210644	Valid's mape: 0.000277677

# %%
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)

# %%
y_ = np.concatenate([np.array([None for i in range(len(y_train)+len(y_val))]) , y_pred])
y_ = pd.DataFrame(y_, index=X.index)

plt.figure(figsize=(16,5))
plt.plot(y, label='original')
plt.plot(y_, '--', label='predict')
plt.legend()

# %%
plt.figure(figsize=(16,5))
plt.plot(y[-10:], label='original')
plt.plot(y_[-10:], '--', label='predict')
plt.legend()

# %%
plt.figure(figsize=(16,5))
plt.plot(y[-100:], label='original')
plt.plot(y_[-100:], '--', label='predict')
plt.legend()

# %%
predict = dataset[len(y_pred)*-1:]
predict
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 14219  105.414  105.434  105.410  105.414   24      9  2020            3
# 14220  105.415  105.428  105.393  105.400   24      9  2020            3
# 14221  105.400  105.414  105.395  105.412   24      9  2020            3
# 14222  105.414  105.435  105.411  105.423   24      9  2020            3
# 14223  105.423  105.444  105.423  105.438   24      9  2020            3
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 28334  107.909  107.915  107.860  107.878   23      4  2021            4
# 28335  107.877  107.895  107.863  107.893   23      4  2021            4
# 28336  107.892  107.902  107.886  107.900   23      4  2021            4
# 28337  107.903  107.904  107.885  107.887   23      4  2021            4
# 28338  107.886  107.908  107.884  107.888   23      4  2021            4
#
#        day_of_year  hour  ...   shift5   shift6   shift7   shift8   shift9  \
# 14219          268     5  ...  105.389  105.383  105.400  105.433  105.436
# 14220          268     6  ...  105.416  105.389  105.383  105.400  105.433
# 14221          268     6  ...  105.471  105.416  105.389  105.383  105.400
# 14222          268     6  ...  105.434  105.471  105.416  105.389  105.383
# 14223          268     6  ...  105.436  105.434  105.471  105.416  105.389
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 28334          113    22  ...  107.958  107.944  107.952  107.944  107.947
# 28335          113    22  ...  107.934  107.958  107.944  107.952  107.944
# 28336          113    23  ...  107.927  107.934  107.958  107.944  107.952
# 28337          113    23  ...  107.927  107.927  107.934  107.958  107.944
# 28338          113    23  ...  107.933  107.927  107.927  107.934  107.958
#
#        shift10  shift11  shift12      sma5       sma15
# 14219  105.406  105.309  105.367  105.4342  105.399133
# 14220  105.436  105.406  105.309  105.4340  105.401867
# 14221  105.433  105.436  105.406  105.4198  105.407267
# 14222  105.400  105.433  105.436  105.4158  105.410400
# 14223  105.383  105.400  105.433  105.4132  105.418000
# ...        ...      ...      ...       ...         ...
# 28334  107.975  107.968  107.968  107.9260  107.944867
# 28335  107.947  107.975  107.968  107.9146  107.940133
# 28336  107.944  107.947  107.975  107.9076  107.937000
# 28337  107.952  107.944  107.947  107.9028  107.932667
# 28338  107.944  107.952  107.944  107.8934  107.927200
#
# [14120 rows x 26 columns]

# %%
predict['predict'] = y_pred
predict
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           open     high      low    close  day  month  year  day_of_week  \
# 14219  105.414  105.434  105.410  105.414   24      9  2020            3
# 14220  105.415  105.428  105.393  105.400   24      9  2020            3
# 14221  105.400  105.414  105.395  105.412   24      9  2020            3
# 14222  105.414  105.435  105.411  105.423   24      9  2020            3
# 14223  105.423  105.444  105.423  105.438   24      9  2020            3
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 28334  107.909  107.915  107.860  107.878   23      4  2021            4
# 28335  107.877  107.895  107.863  107.893   23      4  2021            4
# 28336  107.892  107.902  107.886  107.900   23      4  2021            4
# 28337  107.903  107.904  107.885  107.887   23      4  2021            4
# 28338  107.886  107.908  107.884  107.888   23      4  2021            4
#
#        day_of_year  hour  ...   shift6   shift7   shift8   shift9  shift10  \
# 14219          268     5  ...  105.383  105.400  105.433  105.436  105.406
# 14220          268     6  ...  105.389  105.383  105.400  105.433  105.436
# 14221          268     6  ...  105.416  105.389  105.383  105.400  105.433
# 14222          268     6  ...  105.471  105.416  105.389  105.383  105.400
# 14223          268     6  ...  105.434  105.471  105.416  105.389  105.383
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 28334          113    22  ...  107.944  107.952  107.944  107.947  107.975
# 28335          113    22  ...  107.958  107.944  107.952  107.944  107.947
# 28336          113    23  ...  107.934  107.958  107.944  107.952  107.944
# 28337          113    23  ...  107.927  107.934  107.958  107.944  107.952
# 28338          113    23  ...  107.927  107.927  107.934  107.958  107.944
#
#        shift11  shift12      sma5       sma15     predict
# 14219  105.309  105.367  105.4342  105.399133  105.453756
# 14220  105.406  105.309  105.4340  105.401867  105.455388
# 14221  105.436  105.406  105.4198  105.407267  105.452547
# 14222  105.433  105.436  105.4158  105.410400  105.457189
# 14223  105.400  105.433  105.4132  105.418000  105.505847
# ...        ...      ...       ...         ...         ...
# 28334  107.968  107.968  107.9260  107.944867  107.910151
# 28335  107.975  107.968  107.9146  107.940133  107.901455
# 28336  107.947  107.975  107.9076  107.937000  107.935422
# 28337  107.944  107.947  107.9028  107.932667  107.918211
# 28338  107.952  107.944  107.8934  107.927200  107.918765
#
# [14120 rows x 27 columns]

# %%
predict[['y', 'close', 'predict']]
# Out:
#              y    close     predict
# 14219  105.428  105.414  105.453756
# 14220  105.414  105.400  105.455388
# 14221  105.435  105.412  105.452547
# 14222  105.444  105.423  105.457189
# 14223  105.440  105.438  105.505847
# ...        ...      ...         ...
# 28334  107.895  107.878  107.910151
# 28335  107.902  107.893  107.901455
# 28336  107.904  107.900  107.935422
# 28337  107.908  107.887  107.918211
# 28338  107.903  107.888  107.918765
#
# [14120 rows x 3 columns]

# %%
predict['diff_pred'] = predict['predict'] - predict['close']
predict['diff_act'] = predict['y'] - predict['close']
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
predict[['y', 'close', 'predict', 'diff_pred', 'diff_act']]
# Out:
#              y    close     predict  diff_pred  diff_act
# 14219  105.428  105.414  105.453756   0.039756     0.014
# 14220  105.414  105.400  105.455388   0.055388     0.014
# 14221  105.435  105.412  105.452547   0.040547     0.023
# 14222  105.444  105.423  105.457189   0.034189     0.021
# 14223  105.440  105.438  105.505847   0.067847     0.002
# ...        ...      ...         ...        ...       ...
# 28334  107.895  107.878  107.910151   0.032151     0.017
# 28335  107.902  107.893  107.901455   0.008455     0.009
# 28336  107.904  107.900  107.935422   0.035422     0.004
# 28337  107.908  107.887  107.918211   0.031211     0.021
# 28338  107.903  107.888  107.918765   0.030765     0.015
#
# [14120 rows x 5 columns]

# %%
predict['diff'] = predict['diff_pred'].apply(lambda x: 1 if x >= 0.02 else 0)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
predict[predict['diff'] == 1]['diff_act'].sum(), predict[predict['diff'] != 1]['diff_act'].sum()
# Out:
# (293.9809999999997, 58.55500000000008)

# %%
predict[predict['diff'] == 1]['diff_act'][-100:]
# Out:
# 28230    0.054
# 28232    0.002
# 28233    0.000
# 28234    0.031
# 28235    0.041
#          ...
# 28333    0.008
# 28334    0.017
# 28336    0.004
# 28337    0.021
# 28338    0.015
# Name: diff_act, Length: 100, dtype: float64

# %%
predict[predict['diff'] == 1]['diff_pred'].sum(), predict[predict['diff'] != 1]['diff_pred'].sum()
# Out:
# (1402.5490808507298, -68.46294669877591)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

folds = KFold(n_splits = 5, shuffle = False)

# params = {'max_depth': [5, 7, 9, 11], 'random_state': [0], 'n_estimators': list(range(50, 200, 50)), 'learning_rate': [0.1, 0.01, 0.001], 'n_estimators': [100, 500]}
# params = {'max_depth': list(range(2, 10)), 'random_state': [0], 'n_estimators': list(range(50, 200, 50)), 'learning_rate': [0.1, 0.01, 0.001], 'n_estimators': [100, 500]}
# params = {'max_depth': list(range(2, 10)), 'random_state': [0], 'n_estimators': list(range(50, 200, 50))}
params = {'max_depth': [5, 6, 7], 'random_state': [0], 'n_estimators': [500], 'learning_rate': [.03, .05, .07], 'min_child_weight': [4]}

# XGBoost
xgb = XGBRegressor()

reg_cv_xgb = GridSearchCV(xgb, params, cv=folds, return_train_score=True)
reg_cv_xgb.fit(X, y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, mo...,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'learning_rate': [0.03, 0.05, 0.07],
#                          'max_depth': [5, 6, 7], 'min_child_weight': [4],
#                          'n_estimators': [500], 'random_state': [0]},
#              return_train_score=True)

# %%
print(reg_cv_xgb.best_params_)
y_pred = reg_cv_xgb.predict(X_test)
y_pred
# Out:
# {'learning_rate': 0.03, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 500, 'random_state': 0}
# array([105.43984 , 105.437416, 105.40521 , ..., 107.897125, 107.89858 ,
#        107.89765 ], dtype=float32)

# %%
y_ = np.concatenate([np.array([None for i in range(len(y_train)+len(y_val))]) , y_pred])
y_ = pd.DataFrame(y_, index=X.index)

plt.figure(figsize=(16,5))
plt.plot(y, label='original')
plt.plot(y_, '--', label='predict')
plt.legend()

# %%
plt.figure(figsize=(16,5))
plt.plot(y[-50:], label='original')
plt.plot(y_[-50:], '--', label='predict')
plt.legend()

# %%
plt.figure(figsize=(16,5))
plt.plot(y[-200:], label='original')
plt.plot(y_[-200:], '--', label='predict')
plt.legend()

# %%
import pickle

filename='model.pkl'
pickle.dump(reg_cv_xgb.best_estimator_, open(filename, 'wb'))

# %%
X.columns.tolist()
# Out:
# ['open',
#  'high',
#  'low',
#  'close',
#  'day',
#  'month',
#  'year',
#  'day_of_week',
#  'day_of_year',
#  'hour',
#  'minute',
#  'shift1',
#  'shift2',
#  'shift3',
#  'shift4',
#  'shift5',
#  'shift6',
#  'shift7',
#  'shift8',
#  'shift9',
#  'shift10',
#  'shift11',
#  'shift12',
#  'sma5',
#  'sma15']

# %%
X_test
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 14219  105.414  105.434  105.410  105.414   24      9  2020            3
# 14220  105.415  105.428  105.393  105.400   24      9  2020            3
# 14221  105.400  105.414  105.395  105.412   24      9  2020            3
# 14222  105.414  105.435  105.411  105.423   24      9  2020            3
# 14223  105.423  105.444  105.423  105.438   24      9  2020            3
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 28334  107.909  107.915  107.860  107.878   23      4  2021            4
# 28335  107.877  107.895  107.863  107.893   23      4  2021            4
# 28336  107.892  107.902  107.886  107.900   23      4  2021            4
# 28337  107.903  107.904  107.885  107.887   23      4  2021            4
# 28338  107.886  107.908  107.884  107.888   23      4  2021            4
#
#        day_of_year  hour  ...   shift5   shift6   shift7   shift8   shift9  \
# 14219          268     5  ...  105.389  105.383  105.400  105.433  105.436
# 14220          268     6  ...  105.416  105.389  105.383  105.400  105.433
# 14221          268     6  ...  105.471  105.416  105.389  105.383  105.400
# 14222          268     6  ...  105.434  105.471  105.416  105.389  105.383
# 14223          268     6  ...  105.436  105.434  105.471  105.416  105.389
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 28334          113    22  ...  107.958  107.944  107.952  107.944  107.947
# 28335          113    22  ...  107.934  107.958  107.944  107.952  107.944
# 28336          113    23  ...  107.927  107.934  107.958  107.944  107.952
# 28337          113    23  ...  107.927  107.927  107.934  107.958  107.944
# 28338          113    23  ...  107.933  107.927  107.927  107.934  107.958
#
#        shift10  shift11  shift12      sma5       sma15
# 14219  105.406  105.309  105.367  105.4342  105.399133
# 14220  105.436  105.406  105.309  105.4340  105.401867
# 14221  105.433  105.436  105.406  105.4198  105.407267
# 14222  105.400  105.433  105.436  105.4158  105.410400
# 14223  105.383  105.400  105.433  105.4132  105.418000
# ...        ...      ...      ...       ...         ...
# 28334  107.975  107.968  107.968  107.9260  107.944867
# 28335  107.947  107.975  107.968  107.9146  107.940133
# 28336  107.944  107.947  107.975  107.9076  107.937000
# 28337  107.952  107.944  107.947  107.9028  107.932667
# 28338  107.944  107.952  107.944  107.8934  107.927200
#
# [14120 rows x 25 columns]

# %%
model = pickle.load(open('model.pkl','rb'))

# %%
model.predict(X_test)
# Out:
# array([105.43984 , 105.437416, 105.40521 , ..., 107.897125, 107.89858 ,
#        107.89765 ], dtype=float32)
