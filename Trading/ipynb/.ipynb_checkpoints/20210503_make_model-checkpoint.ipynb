# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('inputs/USDJPY_M15.csv', sep='\t', names=('date', 'time', 'open', 'high', 'low', 'close'), usecols=[0, 1, 2, 3, 4, 5], skiprows=1)
# data = pd.read_csv('inputs/USDJPY15.csv', names=('date', 'time', 'open', 'high', 'low', 'close'), usecols=[0, 1, 2, 3, 4, 5], skiprows=1)
data['datetime'] = pd.to_datetime(data['date']  + ' ' + data['time'])
data.drop(['date', 'time'], axis=1, inplace=True)
data
# Out:
#           open     high      low    close            datetime
# 0      107.525  107.552  107.470  107.537 2020-04-01 00:00:00
# 1      107.537  107.555  107.514  107.540 2020-04-01 00:15:00
# 2      107.540  107.563  107.523  107.523 2020-04-01 00:30:00
# 3      107.523  107.527  107.509  107.509 2020-04-01 00:45:00
# 4      107.509  107.551  107.480  107.551 2020-04-01 01:00:00
# ...        ...      ...      ...      ...                 ...
# 27206  109.432  109.475  109.401  109.426 2021-05-05 09:45:00
# 27207  109.427  109.445  109.391  109.431 2021-05-05 10:00:00
# 27208  109.432  109.438  109.388  109.420 2021-05-05 10:15:00
# 27209  109.419  109.462  109.418  109.444 2021-05-05 10:30:00
# 27210  109.444  109.453  109.437  109.444 2021-05-05 10:45:00
#
# [27211 rows x 5 columns]

# %%
# all_data = pd.merge(data, ni225, on='datetime', suffixes=['', '_ni225']).drop(['date_ni225', 'time_ni225'], axis=1)
all_data = data.copy()
all_data
# Out:
#           open     high      low    close            datetime
# 0      107.525  107.552  107.470  107.537 2020-04-01 00:00:00
# 1      107.537  107.555  107.514  107.540 2020-04-01 00:15:00
# 2      107.540  107.563  107.523  107.523 2020-04-01 00:30:00
# 3      107.523  107.527  107.509  107.509 2020-04-01 00:45:00
# 4      107.509  107.551  107.480  107.551 2020-04-01 01:00:00
# ...        ...      ...      ...      ...                 ...
# 27206  109.432  109.475  109.401  109.426 2021-05-05 09:45:00
# 27207  109.427  109.445  109.391  109.431 2021-05-05 10:00:00
# 27208  109.432  109.438  109.388  109.420 2021-05-05 10:15:00
# 27209  109.419  109.462  109.418  109.444 2021-05-05 10:30:00
# 27210  109.444  109.453  109.437  109.444 2021-05-05 10:45:00
#
# [27211 rows x 5 columns]

# %%
# extract features from date
all_data['day'] = [i.day for i in all_data['datetime']]
all_data['month'] = [i.month for i in all_data['datetime']]
all_data['year'] = [i.year for i in all_data['datetime']]
all_data['day_of_week'] = [i.dayofweek for i in all_data['datetime']]
all_data['day_of_year'] = [i.dayofyear for i in all_data['datetime']]

all_data['hour'] = [i.hour for i in all_data['datetime']]
all_data['minute'] = [i.minute for i in all_data['datetime']]

all_data
# Out:
#           open     high      low    close            datetime  day  month  \
# 0      107.525  107.552  107.470  107.537 2020-04-01 00:00:00    1      4
# 1      107.537  107.555  107.514  107.540 2020-04-01 00:15:00    1      4
# 2      107.540  107.563  107.523  107.523 2020-04-01 00:30:00    1      4
# 3      107.523  107.527  107.509  107.509 2020-04-01 00:45:00    1      4
# 4      107.509  107.551  107.480  107.551 2020-04-01 01:00:00    1      4
# ...        ...      ...      ...      ...                 ...  ...    ...
# 27206  109.432  109.475  109.401  109.426 2021-05-05 09:45:00    5      5
# 27207  109.427  109.445  109.391  109.431 2021-05-05 10:00:00    5      5
# 27208  109.432  109.438  109.388  109.420 2021-05-05 10:15:00    5      5
# 27209  109.419  109.462  109.418  109.444 2021-05-05 10:30:00    5      5
# 27210  109.444  109.453  109.437  109.444 2021-05-05 10:45:00    5      5
#
#        year  day_of_week  day_of_year  hour  minute
# 0      2020            2           92     0       0
# 1      2020            2           92     0      15
# 2      2020            2           92     0      30
# 3      2020            2           92     0      45
# 4      2020            2           92     1       0
# ...     ...          ...          ...   ...     ...
# 27206  2021            2          125     9      45
# 27207  2021            2          125    10       0
# 27208  2021            2          125    10      15
# 27209  2021            2          125    10      30
# 27210  2021            2          125    10      45
#
# [27211 rows x 12 columns]

# %%
# dataset = all_data[['open', 'high', 'low', 'close', 'tickvol', 'day', 'month', 'year', 'day_of_week', 'day_of_year', 'hour', 'minute', 'open_ni225', 'high_ni225', 'low_ni225', 'close_ni225', 'tickvol_ni225']]
dataset = all_data[['open', 'high', 'low', 'close', 'day', 'month', 'year', 'day_of_week', 'day_of_year', 'hour', 'minute']]
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 0      107.525  107.552  107.470  107.537    1      4  2020            2
# 1      107.537  107.555  107.514  107.540    1      4  2020            2
# 2      107.540  107.563  107.523  107.523    1      4  2020            2
# 3      107.523  107.527  107.509  107.509    1      4  2020            2
# 4      107.509  107.551  107.480  107.551    1      4  2020            2
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 27206  109.432  109.475  109.401  109.426    5      5  2021            2
# 27207  109.427  109.445  109.391  109.431    5      5  2021            2
# 27208  109.432  109.438  109.388  109.420    5      5  2021            2
# 27209  109.419  109.462  109.418  109.444    5      5  2021            2
# 27210  109.444  109.453  109.437  109.444    5      5  2021            2
#
#        day_of_year  hour  minute
# 0               92     0       0
# 1               92     0      15
# 2               92     0      30
# 3               92     0      45
# 4               92     1       0
# ...            ...   ...     ...
# 27206          125     9      45
# 27207          125    10       0
# 27208          125    10      15
# 27209          125    10      30
# 27210          125    10      45
#
# [27211 rows x 11 columns]

# %%
dataset['y'] = dataset['high'].shift(-1)
dataset[['y', 'high']]
# Out:
#              y     high
# 0      107.555  107.552
# 1      107.563  107.555
# 2      107.527  107.563
# 3      107.551  107.527
# 4      107.554  107.551
# ...        ...      ...
# 27206  109.445  109.475
# 27207  109.438  109.445
# 27208  109.462  109.438
# 27209  109.453  109.462
# 27210      NaN  109.453
#
# [27211 rows x 2 columns]

# %%
for i in range(1, 13):
    dataset['shift%s'%i] = dataset['high'].shift(i)

dataset['sma5'] = dataset['high'].rolling(5).mean()
dataset['sma15'] = dataset['high'].rolling(15).mean()
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 0      107.525  107.552  107.470  107.537    1      4  2020            2
# 1      107.537  107.555  107.514  107.540    1      4  2020            2
# 2      107.540  107.563  107.523  107.523    1      4  2020            2
# 3      107.523  107.527  107.509  107.509    1      4  2020            2
# 4      107.509  107.551  107.480  107.551    1      4  2020            2
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 27206  109.432  109.475  109.401  109.426    5      5  2021            2
# 27207  109.427  109.445  109.391  109.431    5      5  2021            2
# 27208  109.432  109.438  109.388  109.420    5      5  2021            2
# 27209  109.419  109.462  109.418  109.444    5      5  2021            2
# 27210  109.444  109.453  109.437  109.444    5      5  2021            2
#
#        day_of_year  hour  ...   shift5   shift6   shift7   shift8   shift9  \
# 0               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 1               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 2               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 3               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 4               92     1  ...      NaN      NaN      NaN      NaN      NaN
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 27206          125     9  ...  109.347  109.332  109.336  109.331  109.310
# 27207          125    10  ...  109.391  109.347  109.332  109.336  109.331
# 27208          125    10  ...  109.413  109.391  109.347  109.332  109.336
# 27209          125    10  ...  109.466  109.413  109.391  109.347  109.332
# 27210          125    10  ...  109.479  109.466  109.413  109.391  109.347
#
#        shift10  shift11  shift12      sma5       sma15
# 0          NaN      NaN      NaN       NaN         NaN
# 1          NaN      NaN      NaN       NaN         NaN
# 2          NaN      NaN      NaN       NaN         NaN
# 3          NaN      NaN      NaN       NaN         NaN
# 4          NaN      NaN      NaN  107.5496         NaN
# ...        ...      ...      ...       ...         ...
# 27206  109.300  109.295  109.280  109.4448  109.352400
# 27207  109.310  109.300  109.295  109.4556  109.365533
# 27208  109.331  109.310  109.300  109.4606  109.375867
# 27209  109.336  109.331  109.310  109.4598  109.388000
# 27210  109.332  109.336  109.331  109.4546  109.398533
#
# [27211 rows x 26 columns]

# %%
dataset = dataset[100:-1]
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 100    107.101  107.175  107.078  107.145    2      4  2020            3
# 101    107.145  107.199  107.118  107.122    2      4  2020            3
# 102    107.122  107.153  107.074  107.145    2      4  2020            3
# 103    107.145  107.231  107.145  107.198    2      4  2020            3
# 104    107.200  107.259  107.184  107.217    2      4  2020            3
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 27205  109.437  109.479  109.428  109.431    5      5  2021            2
# 27206  109.432  109.475  109.401  109.426    5      5  2021            2
# 27207  109.427  109.445  109.391  109.431    5      5  2021            2
# 27208  109.432  109.438  109.388  109.420    5      5  2021            2
# 27209  109.419  109.462  109.418  109.444    5      5  2021            2
#
#        day_of_year  hour  ...   shift5   shift6   shift7   shift8   shift9  \
# 100             93     1  ...  107.186  107.194  107.134  107.133  107.160
# 101             93     1  ...  107.160  107.186  107.194  107.134  107.133
# 102             93     1  ...  107.130  107.160  107.186  107.194  107.134
# 103             93     1  ...  107.074  107.130  107.160  107.186  107.194
# 104             93     2  ...  107.110  107.074  107.130  107.160  107.186
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 27205          125     9  ...  109.332  109.336  109.331  109.310  109.300
# 27206          125     9  ...  109.347  109.332  109.336  109.331  109.310
# 27207          125    10  ...  109.391  109.347  109.332  109.336  109.331
# 27208          125    10  ...  109.413  109.391  109.347  109.332  109.336
# 27209          125    10  ...  109.466  109.413  109.391  109.347  109.332
#
#        shift10  shift11  shift12      sma5       sma15
# 100    107.054  107.186  107.232  107.1298  107.161667
# 101    107.160  107.054  107.186  107.1376  107.157400
# 102    107.133  107.160  107.054  107.1422  107.152000
# 103    107.134  107.133  107.160  107.1736  107.151933
# 104    107.194  107.134  107.133  107.2034  107.156800
# ...        ...      ...      ...       ...         ...
# 27205  109.295  109.280  109.283  109.4192  109.337400
# 27206  109.300  109.295  109.280  109.4448  109.352400
# 27207  109.310  109.300  109.295  109.4556  109.365533
# 27208  109.331  109.310  109.300  109.4606  109.375867
# 27209  109.336  109.331  109.310  109.4598  109.388000
#
# [27110 rows x 26 columns]

# %%
dataset[['y', 'high']]
# Out:
#              y     high
# 100    107.199  107.175
# 101    107.153  107.199
# 102    107.231  107.153
# 103    107.259  107.231
# 104    107.278  107.259
# ...        ...      ...
# 27205  109.475  109.479
# 27206  109.445  109.475
# 27207  109.438  109.445
# 27208  109.462  109.438
# 27209  109.453  109.462
#
# [27110 rows x 2 columns]

# %%
dataset.isnull().any()
# Out:
# open           False
# high           False
# low            False
# close          False
# day            False
# month          False
# year           False
# day_of_week    False
# day_of_year    False
# hour           False
# minute         False
# y              False
# shift1         False
# shift2         False
# shift3         False
# shift4         False
# shift5         False
# shift6         False
# shift7         False
# shift8         False
# shift9         False
# shift10        False
# shift11        False
# shift12        False
# sma5           False
# sma15          False
# dtype: bool

# %%
X = dataset.drop(['y'], axis=1)
y = dataset['y']

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, train_test_split

# %%
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
# X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.3, shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

folds = KFold(n_splits = 5, shuffle = True)

# params = {'max_depth': [5, 7, 9, 11], 'random_state': [0], 'n_estimators': list(range(50, 200, 50)), 'learning_rate': [0.1, 0.01, 0.001], 'n_estimators': [100, 500]}
params = {'objective': ['reg:squarederror'], 'max_depth': list(range(2, 10)), 'random_state': [0], 'n_estimators': list(range(50, 200, 50)), 'learning_rate': [0.1, 0.01, 0.001]}
# params = {'max_depth': list(range(2, 10)), 'random_state': [0], 'n_estimators': list(range(50, 200, 50))}
# params = {'max_depth': [5, 6, 7], 'random_state': [0], 'n_estimators': [500], 'learning_rate': [.03, .05, .07], 'min_child_weight': [4]}
# params = {'max_depth': list(range(2, 10)), 'random_state': [0], 'n_estimators': list(range(50, 200, 50))}

# XGBoost
xgb = XGBRegressor()

reg_cv_xgb = GridSearchCV(xgb, params, cv=folds, return_train_score=True, verbose=100)
reg_cv_xgb.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.9s
# [CV 2/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.8s
# [CV 3/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.8s
# [CV 4/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.7s
# [CV 5/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.8s
# [CV 1/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.4s
# [CV 2/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 3/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.7s
# [CV 4/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.1s
# [CV 5/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.7s
# [CV 1/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.5s
# [CV 2/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.4s
# [CV 3/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.1s
# [CV 4/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.2s
# [CV 5/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.9s
# [CV 1/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   3.2s
# [CV 2/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 3/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 4/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 5/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 1/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.8s
# [CV 2/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.9s
# [CV 3/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.8s
# [CV 4/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.2s
# [CV 5/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.7s
# [CV 1/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.2s
# [CV 2/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.6s
# [CV 3/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  12.8s
# [CV 4/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.9s
# [CV 5/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.7s
# [CV 1/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.8s
# [CV 2/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 3/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.6s
# [CV 4/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 5/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 1/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.5s
# [CV 2/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.1s
# [CV 3/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.2s
# [CV 4/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   7.6s
# [CV 5/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.0s
# [CV 1/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  11.8s
# [CV 2/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  10.8s
# [CV 3/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  12.9s
# [CV 4/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.6s
# [CV 5/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.8s
# [CV 1/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 2/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 3/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.6s
# [CV 4/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.7s
# [CV 5/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.6s
# [CV 1/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   7.0s
# [CV 2/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.9s
# [CV 3/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   7.5s
# [CV 4/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   7.9s
# [CV 5/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.8s
# [CV 1/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  11.9s
# [CV 2/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  11.0s
# [CV 3/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  11.4s
# [CV 4/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  11.6s
# [CV 5/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  11.0s
# [CV 1/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 2/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.6s
# [CV 3/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.7s
# [CV 4/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.7s
# [CV 5/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.7s
# [CV 1/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   7.7s
# [CV 2/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   9.8s
# [CV 3/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   8.5s
# [CV 4/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   8.1s
# [CV 5/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   7.9s
# [CV 1/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  13.9s
# [CV 2/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  12.8s
# [CV 3/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  12.8s
# [CV 4/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  13.1s
# [CV 5/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  13.3s
# [CV 1/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.6s
# [CV 2/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 3/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.7s
# [CV 4/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.6s
# [CV 5/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 1/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   8.7s
# [CV 2/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   8.5s
# [CV 3/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   9.2s
# [CV 4/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   8.6s
# [CV 5/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   8.6s
# [CV 1/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  15.6s
# [CV 2/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  15.1s
# [CV 3/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  15.0s
# [CV 4/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  15.2s
# [CV 5/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  14.7s
# [CV 1/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.6s
# [CV 2/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 3/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.6s
# [CV 4/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 5/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.7s
# [CV 1/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   9.3s
# [CV 2/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   9.6s
# [CV 3/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   9.5s
# [CV 4/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=  10.3s
# [CV 5/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   9.3s
# [CV 1/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  17.1s
# [CV 2/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  17.1s
# [CV 3/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  17.1s
# [CV 4/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  17.2s
# [CV 5/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  17.5s
# [CV 1/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.4s
# [CV 2/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 3/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 4/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 5/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 1/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=  11.3s
# [CV 2/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=  10.5s
# [CV 3/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=  10.6s
# [CV 4/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=  10.2s
# [CV 5/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=  10.4s
# [CV 1/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  19.5s
# [CV 2/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  19.5s
# [CV 3/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  19.9s
# [CV 4/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  20.2s
# [CV 5/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  20.6s
# [CV 1/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 2/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.7s
# [CV 3/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.8s
# [CV 4/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.6s
# [CV 5/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.6s
# [CV 1/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.6s
# [CV 2/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.9s
# [CV 3/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.9s
# [CV 4/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.0s
# [CV 5/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 1/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.3s
# [CV 2/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.0s
# [CV 3/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.0s
# [CV 4/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.0s
# [CV 5/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.0s
# [CV 1/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 2/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 3/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 4/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   3.9s
# [CV 5/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 1/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.2s
# [CV 2/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.3s
# [CV 3/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.5s
# [CV 4/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 5/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 1/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.1s
# [CV 2/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.0s
# [CV 3/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.1s
# [CV 4/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.3s
# [CV 5/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.8s
# [CV 1/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.9s
# [CV 2/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 3/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.9s
# [CV 4/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.7s
# [CV 5/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 1/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   8.8s
# [CV 2/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   9.5s
# [CV 3/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.5s
# [CV 4/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 5/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 1/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.2s
# [CV 2/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.2s
# [CV 3/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.5s
# [CV 4/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.2s
# [CV 5/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.5s
# [CV 1/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 2/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 3/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 4/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 5/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 1/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 2/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.6s
# [CV 3/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.5s
# [CV 4/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.5s
# [CV 5/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.5s
# [CV 1/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.0s
# [CV 2/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.1s
# [CV 3/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.9s
# [CV 4/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.3s
# [CV 5/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.8s
# [CV 1/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 2/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 3/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 4/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 5/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 1/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.5s
# [CV 2/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 3/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.6s
# [CV 4/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.5s
# [CV 5/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.9s
# [CV 1/5; 39/72] START learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 39/72] END learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.3s
# [CV 2/5; 39/72] START learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 39/72] END learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.4s
# [CV 3/5; 39/72] START learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 39/72] END learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.8s
# [CV 4/5; 39/72] START learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# ...
# [CV 3/5; 61/72] START learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 61/72] END learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 4/5; 61/72] START learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 61/72] END learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 5/5; 61/72] START learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 61/72] END learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 1/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.8s
# [CV 2/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.8s
# [CV 3/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.9s
# [CV 4/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.4s
# [CV 5/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.6s
# [CV 1/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.5s
# [CV 2/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.4s
# [CV 3/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.1s
# [CV 4/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.9s
# [CV 5/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.8s
# [CV 1/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 2/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.9s
# [CV 3/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.8s
# [CV 4/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.7s
# [CV 5/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.8s
# [CV 1/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 2/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 3/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.9s
# [CV 4/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.2s
# [CV 5/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.0s
# [CV 1/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.3s
# [CV 2/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.7s
# [CV 3/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.1s
# [CV 4/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.2s
# [CV 5/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.9s
# [CV 1/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.9s
# [CV 2/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.9s
# [CV 3/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 4/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 5/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.5s
# [CV 1/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.5s
# [CV 2/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.7s
# [CV 3/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 4/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.6s
# [CV 5/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.5s
# [CV 1/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.2s
# [CV 2/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.9s
# [CV 3/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.8s
# [CV 4/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.9s
# [CV 5/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.7s
# [CV 1/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 2/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 3/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.6s
# [CV 4/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.8s
# [CV 5/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.7s
# [CV 1/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.2s
# [CV 2/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 3/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.4s
# [CV 4/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.8s
# [CV 5/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.6s
# [CV 1/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.0s
# [CV 2/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.0s
# [CV 3/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.1s
# [CV 4/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   4.1s
# [CV 5/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.2s
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, mon...
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                          'n_estimators': [50, 100, 150],
#                          'objective': ['reg:squarederror'],
#                          'random_state': [0]},
#              return_train_score=True, verbose=100)

# %%
print(reg_cv_xgb.best_params_)
y_pred = reg_cv_xgb.predict(X_val)
y_pred
# Out:
# {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 150, 'objective': 'reg:squarederror', 'random_state': 0}
# array([105.32857 , 105.352516, 105.35266 , ..., 109.42804 , 109.43161 ,
#        109.45669 ], dtype=float32)

# %%
import pickle

filename='model.pkl'
pickle.dump(reg_cv_xgb.best_estimator_, open(filename, 'wb'))

# %%
y_ = np.concatenate([np.array([None for i in range(len(y_train))]) , y_pred])
y_ = pd.DataFrame(y_, index=X.index)

plt.figure(figsize=(16,5))
plt.plot(y, label='original')
plt.plot(y_, '--', label='predict')
plt.legend()
plt.show()

plt.figure(figsize=(16,5))
plt.plot(y[-50:], label='original')
plt.plot(y_[-50:], '--', label='predict')
plt.legend()
plt.show()
