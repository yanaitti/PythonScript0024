# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('inputs/USDJPY_M15.csv', sep='\t', names=('date', 'time', 'open', 'high', 'low', 'close'), usecols=[0, 1, 2, 3, 4, 5], skiprows=1)
# data = pd.read_csv('inputs/USDJPY15.csv', names=('date', 'time', 'open', 'high', 'low', 'close'), usecols=[0, 1, 2, 3, 4, 5], skiprows=1)
data['datetime'] = pd.to_datetime(data['date']  + ' ' + data['time'])
data.drop(['date', 'time'], axis=1, inplace=True)
data
# Out:
#           open     high      low    close            datetime
# 0      107.525  107.552  107.470  107.537 2020-04-01 00:00:00
# 1      107.537  107.555  107.514  107.540 2020-04-01 00:15:00
# 2      107.540  107.563  107.523  107.523 2020-04-01 00:30:00
# 3      107.523  107.527  107.509  107.509 2020-04-01 00:45:00
# 4      107.509  107.551  107.480  107.551 2020-04-01 01:00:00
# ...        ...      ...      ...      ...                 ...
# 27209  109.419  109.462  109.418  109.444 2021-05-05 10:30:00
# 27210  109.444  109.453  109.336  109.367 2021-05-05 10:45:00
# 27211  109.367  109.390  109.321  109.337 2021-05-05 11:00:00
# 27212  109.337  109.357  109.312  109.320 2021-05-05 11:15:00
# 27213  109.321  109.321  109.318  109.318 2021-05-05 11:30:00
#
# [27214 rows x 5 columns]

# %%
# all_data = pd.merge(data, ni225, on='datetime', suffixes=['', '_ni225']).drop(['date_ni225', 'time_ni225'], axis=1)
all_data = data.copy()
all_data
# Out:
#           open     high      low    close            datetime
# 0      107.525  107.552  107.470  107.537 2020-04-01 00:00:00
# 1      107.537  107.555  107.514  107.540 2020-04-01 00:15:00
# 2      107.540  107.563  107.523  107.523 2020-04-01 00:30:00
# 3      107.523  107.527  107.509  107.509 2020-04-01 00:45:00
# 4      107.509  107.551  107.480  107.551 2020-04-01 01:00:00
# ...        ...      ...      ...      ...                 ...
# 27209  109.419  109.462  109.418  109.444 2021-05-05 10:30:00
# 27210  109.444  109.453  109.336  109.367 2021-05-05 10:45:00
# 27211  109.367  109.390  109.321  109.337 2021-05-05 11:00:00
# 27212  109.337  109.357  109.312  109.320 2021-05-05 11:15:00
# 27213  109.321  109.321  109.318  109.318 2021-05-05 11:30:00
#
# [27214 rows x 5 columns]

# %%
# extract features from date
all_data['day'] = [i.day for i in all_data['datetime']]
all_data['month'] = [i.month for i in all_data['datetime']]
all_data['year'] = [i.year for i in all_data['datetime']]
all_data['day_of_week'] = [i.dayofweek for i in all_data['datetime']]
all_data['day_of_year'] = [i.dayofyear for i in all_data['datetime']]

all_data['hour'] = [i.hour for i in all_data['datetime']]
all_data['minute'] = [i.minute for i in all_data['datetime']]

all_data
# Out:
#           open     high      low    close            datetime  day  month  \
# 0      107.525  107.552  107.470  107.537 2020-04-01 00:00:00    1      4
# 1      107.537  107.555  107.514  107.540 2020-04-01 00:15:00    1      4
# 2      107.540  107.563  107.523  107.523 2020-04-01 00:30:00    1      4
# 3      107.523  107.527  107.509  107.509 2020-04-01 00:45:00    1      4
# 4      107.509  107.551  107.480  107.551 2020-04-01 01:00:00    1      4
# ...        ...      ...      ...      ...                 ...  ...    ...
# 27209  109.419  109.462  109.418  109.444 2021-05-05 10:30:00    5      5
# 27210  109.444  109.453  109.336  109.367 2021-05-05 10:45:00    5      5
# 27211  109.367  109.390  109.321  109.337 2021-05-05 11:00:00    5      5
# 27212  109.337  109.357  109.312  109.320 2021-05-05 11:15:00    5      5
# 27213  109.321  109.321  109.318  109.318 2021-05-05 11:30:00    5      5
#
#        year  day_of_week  day_of_year  hour  minute
# 0      2020            2           92     0       0
# 1      2020            2           92     0      15
# 2      2020            2           92     0      30
# 3      2020            2           92     0      45
# 4      2020            2           92     1       0
# ...     ...          ...          ...   ...     ...
# 27209  2021            2          125    10      30
# 27210  2021            2          125    10      45
# 27211  2021            2          125    11       0
# 27212  2021            2          125    11      15
# 27213  2021            2          125    11      30
#
# [27214 rows x 12 columns]

# %%
# dataset = all_data[['open', 'high', 'low', 'close', 'tickvol', 'day', 'month', 'year', 'day_of_week', 'day_of_year', 'hour', 'minute', 'open_ni225', 'high_ni225', 'low_ni225', 'close_ni225', 'tickvol_ni225']]
dataset = all_data[['open', 'high', 'low', 'close', 'day', 'month', 'year', 'day_of_week', 'day_of_year', 'hour', 'minute']]
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 0      107.525  107.552  107.470  107.537    1      4  2020            2
# 1      107.537  107.555  107.514  107.540    1      4  2020            2
# 2      107.540  107.563  107.523  107.523    1      4  2020            2
# 3      107.523  107.527  107.509  107.509    1      4  2020            2
# 4      107.509  107.551  107.480  107.551    1      4  2020            2
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 27209  109.419  109.462  109.418  109.444    5      5  2021            2
# 27210  109.444  109.453  109.336  109.367    5      5  2021            2
# 27211  109.367  109.390  109.321  109.337    5      5  2021            2
# 27212  109.337  109.357  109.312  109.320    5      5  2021            2
# 27213  109.321  109.321  109.318  109.318    5      5  2021            2
#
#        day_of_year  hour  minute
# 0               92     0       0
# 1               92     0      15
# 2               92     0      30
# 3               92     0      45
# 4               92     1       0
# ...            ...   ...     ...
# 27209          125    10      30
# 27210          125    10      45
# 27211          125    11       0
# 27212          125    11      15
# 27213          125    11      30
#
# [27214 rows x 11 columns]

# %%
dataset['y'] = dataset['low'].shift(-1)
dataset[['y', 'low']]
# Out:
#              y      low
# 0      107.514  107.470
# 1      107.523  107.514
# 2      107.509  107.523
# 3      107.480  107.509
# 4      107.519  107.480
# ...        ...      ...
# 27209  109.336  109.418
# 27210  109.321  109.336
# 27211  109.312  109.321
# 27212  109.318  109.312
# 27213      NaN  109.318
#
# [27214 rows x 2 columns]

# %%
for i in range(1, 13):
    dataset['shift%s'%i] = dataset['low'].shift(i)

dataset['sma5'] = dataset['low'].rolling(5).mean()
dataset['sma10'] = dataset['low'].rolling(10).mean()
dataset['sma15'] = dataset['low'].rolling(15).mean()
# dataset['diff_hl'] = dataset['high'] - dataset['low']
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 0      107.525  107.552  107.470  107.537    1      4  2020            2
# 1      107.537  107.555  107.514  107.540    1      4  2020            2
# 2      107.540  107.563  107.523  107.523    1      4  2020            2
# 3      107.523  107.527  107.509  107.509    1      4  2020            2
# 4      107.509  107.551  107.480  107.551    1      4  2020            2
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 27209  109.419  109.462  109.418  109.444    5      5  2021            2
# 27210  109.444  109.453  109.336  109.367    5      5  2021            2
# 27211  109.367  109.390  109.321  109.337    5      5  2021            2
# 27212  109.337  109.357  109.312  109.320    5      5  2021            2
# 27213  109.321  109.321  109.318  109.318    5      5  2021            2
#
#        day_of_year  hour  ...   shift6   shift7   shift8   shift9  shift10  \
# 0               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 1               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 2               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 3               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 4               92     1  ...      NaN      NaN      NaN      NaN      NaN
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 27209          125    10  ...  109.369  109.343  109.319  109.300  109.313
# 27210          125    10  ...  109.387  109.369  109.343  109.319  109.300
# 27211          125    11  ...  109.428  109.387  109.369  109.343  109.319
# 27212          125    11  ...  109.401  109.428  109.387  109.369  109.343
# 27213          125    11  ...  109.391  109.401  109.428  109.387  109.369
#
#        shift11  shift12      sma5     sma10       sma15
# 0          NaN      NaN       NaN       NaN         NaN
# 1          NaN      NaN       NaN       NaN         NaN
# 2          NaN      NaN       NaN       NaN         NaN
# 3          NaN      NaN       NaN       NaN         NaN
# 4          NaN      NaN  107.4992       NaN         NaN
# ...        ...      ...       ...       ...         ...
# 27209  109.303  109.290  109.4052  109.3744  109.346600
# 27210  109.313  109.303  109.3868  109.3780  109.350933
# 27211  109.300  109.313  109.3708  109.3782  109.353800
# 27212  109.319  109.300  109.3550  109.3751  109.355267
# 27213  109.343  109.319  109.3410  109.3700  109.356267
#
# [27214 rows x 27 columns]

# %%
dataset = dataset[100:-1]
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 100    107.101  107.175  107.078  107.145    2      4  2020            3
# 101    107.145  107.199  107.118  107.122    2      4  2020            3
# 102    107.122  107.153  107.074  107.145    2      4  2020            3
# 103    107.145  107.231  107.145  107.198    2      4  2020            3
# 104    107.200  107.259  107.184  107.217    2      4  2020            3
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 27208  109.432  109.438  109.388  109.420    5      5  2021            2
# 27209  109.419  109.462  109.418  109.444    5      5  2021            2
# 27210  109.444  109.453  109.336  109.367    5      5  2021            2
# 27211  109.367  109.390  109.321  109.337    5      5  2021            2
# 27212  109.337  109.357  109.312  109.320    5      5  2021            2
#
#        day_of_year  hour  ...   shift6   shift7   shift8   shift9  shift10  \
# 100             93     1  ...  107.132  107.046  107.047  106.960  106.917
# 101             93     1  ...  107.139  107.132  107.046  107.047  106.960
# 102             93     1  ...  107.130  107.139  107.132  107.046  107.047
# 103             93     1  ...  107.040  107.130  107.139  107.132  107.046
# 104             93     2  ...  107.054  107.040  107.130  107.139  107.132
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 27208          125    10  ...  109.343  109.319  109.300  109.313  109.303
# 27209          125    10  ...  109.369  109.343  109.319  109.300  109.313
# 27210          125    10  ...  109.387  109.369  109.343  109.319  109.300
# 27211          125    11  ...  109.428  109.387  109.369  109.343  109.319
# 27212          125    11  ...  109.401  109.428  109.387  109.369  109.343
#
#        shift11  shift12      sma5     sma10       sma15
# 100    107.023  107.094  107.0720  107.0684  107.063267
# 101    106.917  107.023  107.0696  107.0842  107.062333
# 102    106.960  106.917  107.0764  107.0869  107.060667
# 103    107.047  106.960  107.0946  107.0968  107.064067
# 104    107.046  107.047  107.1198  107.1020  107.074800
# ...        ...      ...       ...       ...         ...
# 27208  109.290  109.278  109.3990  109.3639  109.335600
# 27209  109.303  109.290  109.4052  109.3744  109.346600
# 27210  109.313  109.303  109.3868  109.3780  109.350933
# 27211  109.300  109.313  109.3708  109.3782  109.353800
# 27212  109.319  109.300  109.3550  109.3751  109.355267
#
# [27113 rows x 27 columns]

# %%
dataset[['y', 'high']]
# Out:
#              y     high
# 100    107.118  107.175
# 101    107.074  107.199
# 102    107.145  107.153
# 103    107.184  107.231
# 104    107.207  107.259
# ...        ...      ...
# 27208  109.418  109.438
# 27209  109.336  109.462
# 27210  109.321  109.453
# 27211  109.312  109.390
# 27212  109.318  109.357
#
# [27113 rows x 2 columns]

# %%
dataset.isnull().any()
# Out:
# open           False
# high           False
# low            False
# close          False
# day            False
# month          False
# year           False
# day_of_week    False
# day_of_year    False
# hour           False
# minute         False
# y              False
# shift1         False
# shift2         False
# shift3         False
# shift4         False
# shift5         False
# shift6         False
# shift7         False
# shift8         False
# shift9         False
# shift10        False
# shift11        False
# shift12        False
# sma5           False
# sma10          False
# sma15          False
# dtype: bool

# %%
X = dataset.drop(['y'], axis=1)
y = dataset['y']

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, train_test_split

# %%
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
# X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.3, shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

folds = KFold(n_splits = 5, shuffle = True)

# params = {'max_depth': [5, 7, 9, 11], 'random_state': [0], 'n_estimators': list(range(50, 200, 50)), 'learning_rate': [0.1, 0.01, 0.001], 'n_estimators': [100, 500]}
params = {'objective': ['reg:squarederror'], 'max_depth': list(range(2, 10)), 'random_state': [0], 'n_estimators': list(range(50, 200, 50)), 'learning_rate': [0.1, 0.01, 0.001]}
# params = {'max_depth': list(range(2, 10)), 'random_state': [0], 'n_estimators': list(range(50, 200, 50))}
# params = {'max_depth': [5, 6, 7], 'random_state': [0], 'n_estimators': [500], 'learning_rate': [.03, .05, .07], 'min_child_weight': [4]}
# params = {'max_depth': list(range(2, 10)), 'random_state': [0], 'n_estimators': list(range(50, 200, 50))}

# XGBoost
xgb = XGBRegressor()

reg_cv_xgb = GridSearchCV(xgb, params, cv=folds, return_train_score=True, verbose=100)
reg_cv_xgb.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 2/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.1s
# [CV 3/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 4/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.1s
# [CV 5/5; 1/72] START learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 1/72] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.2s
# [CV 1/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 2/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 3/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 4/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 5/5; 2/72] START learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 2/72] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 1/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 2/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 3/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 4/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 5/5; 3/72] START learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 3/72] END learning_rate=0.1, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 1/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.4s
# [CV 2/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.4s
# [CV 3/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.4s
# [CV 4/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.4s
# [CV 5/5; 4/72] START learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 4/72] END learning_rate=0.1, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.4s
# [CV 1/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 2/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 3/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 4/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 5/5; 5/72] START learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 5/72] END learning_rate=0.1, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 1/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 2/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 3/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 4/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 5/5; 6/72] START learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 6/72] END learning_rate=0.1, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 1/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 2/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 3/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 4/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 5/5; 7/72] START learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 7/72] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 1/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 2/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 3/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 4/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 5/5; 8/72] START learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 8/72] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 1/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.6s
# [CV 2/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.5s
# [CV 3/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.5s
# [CV 4/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.5s
# [CV 5/5; 9/72] START learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 9/72] END learning_rate=0.1, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   5.5s
# [CV 1/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.6s
# [CV 2/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 3/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 4/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 5/5; 10/72] START learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 10/72] END learning_rate=0.1, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 1/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.1s
# [CV 2/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.0s
# [CV 3/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.0s
# [CV 4/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.0s
# [CV 5/5; 11/72] START learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 11/72] END learning_rate=0.1, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.0s
# [CV 1/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.0s
# [CV 2/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.5s
# [CV 3/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.3s
# [CV 4/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.4s
# [CV 5/5; 12/72] START learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 12/72] END learning_rate=0.1, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   6.3s
# [CV 1/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 2/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 3/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 4/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 5/5; 13/72] START learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 13/72] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 1/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 2/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 3/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 4/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 5/5; 14/72] START learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 14/72] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.4s
# [CV 1/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.8s
# [CV 2/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.4s
# [CV 3/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.5s
# [CV 4/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.6s
# [CV 5/5; 15/72] START learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 15/72] END learning_rate=0.1, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   7.4s
# [CV 1/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 2/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 3/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 4/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 5/5; 16/72] START learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 16/72] END learning_rate=0.1, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 1/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.9s
# [CV 2/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.8s
# [CV 3/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.9s
# [CV 4/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.0s
# [CV 5/5; 17/72] START learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 17/72] END learning_rate=0.1, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   4.8s
# [CV 1/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.6s
# [CV 2/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.7s
# [CV 3/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.5s
# [CV 4/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.6s
# [CV 5/5; 18/72] START learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 18/72] END learning_rate=0.1, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   8.5s
# [CV 1/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 2/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 3/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 4/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 5/5; 19/72] START learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 19/72] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 1/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.6s
# [CV 2/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.5s
# [CV 3/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.5s
# [CV 4/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.4s
# [CV 5/5; 20/72] START learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 20/72] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.4s
# [CV 1/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  10.1s
# [CV 2/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.8s
# [CV 3/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.8s
# [CV 4/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.8s
# [CV 5/5; 21/72] START learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 21/72] END learning_rate=0.1, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   9.8s
# [CV 1/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 2/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 3/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 4/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 5/5; 22/72] START learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 22/72] END learning_rate=0.1, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.5s
# [CV 1/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.2s
# [CV 2/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.1s
# [CV 3/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   5.9s
# [CV 4/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.1s
# [CV 5/5; 23/72] START learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 23/72] END learning_rate=0.1, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   6.0s
# [CV 1/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  11.0s
# [CV 2/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  11.0s
# [CV 3/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  10.7s
# [CV 4/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  10.9s
# [CV 5/5; 24/72] START learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 24/72] END learning_rate=0.1, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=  10.7s
# [CV 1/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 2/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 3/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 4/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 5/5; 25/72] START learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 25/72] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 1/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 2/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   1.9s
# [CV 3/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 4/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 5/5; 26/72] START learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 26/72] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 1/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 2/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 3/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 4/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 5/5; 27/72] START learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 27/72] END learning_rate=0.01, max_depth=2, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 1/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 2/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 3/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 4/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 5/5; 28/72] START learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 28/72] END learning_rate=0.01, max_depth=3, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 1/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 2/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 3/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 4/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 5/5; 29/72] START learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 29/72] END learning_rate=0.01, max_depth=3, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 1/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 2/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.6s
# [CV 3/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 4/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.7s
# [CV 5/5; 30/72] START learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 30/72] END learning_rate=0.01, max_depth=3, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.6s
# [CV 1/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 2/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 3/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 4/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 5/5; 31/72] START learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 31/72] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 1/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 2/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 3/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 4/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 5/5; 32/72] START learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 32/72] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 1/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 2/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 3/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 4/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 5/5; 33/72] START learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 33/72] END learning_rate=0.01, max_depth=4, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 1/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 2/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 3/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 4/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 5/5; 34/72] START learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 34/72] END learning_rate=0.01, max_depth=5, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 1/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 2/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 3/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 4/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 5/5; 35/72] START learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 35/72] END learning_rate=0.01, max_depth=5, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 1/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.6s
# [CV 2/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.6s
# [CV 3/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 4/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 5/5; 36/72] START learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 36/72] END learning_rate=0.01, max_depth=5, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 1/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 2/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 3/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 4/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 5/5; 37/72] START learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 37/72] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 1/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 2/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 3/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 4/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.3s
# [CV 5/5; 38/72] START learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 38/72] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.2s
# [CV 1/5; 39/72] START learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 39/72] END learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.6s
# [CV 2/5; 39/72] START learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 39/72] END learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.7s
# [CV 3/5; 39/72] START learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 39/72] END learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.5s
# [CV 4/5; 39/72] START learning_rate=0.01, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# ...
# [CV 3/5; 61/72] START learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 61/72] END learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 4/5; 61/72] START learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 61/72] END learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 5/5; 61/72] START learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 61/72] END learning_rate=0.001, max_depth=6, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 1/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 2/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 3/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   1.9s
# [CV 4/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 5/5; 62/72] START learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 62/72] END learning_rate=0.001, max_depth=6, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   1.9s
# [CV 1/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 2/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 3/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 4/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 5/5; 63/72] START learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 63/72] END learning_rate=0.001, max_depth=6, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 1/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 2/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.1s
# [CV 3/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.1s
# [CV 4/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 5/5; 64/72] START learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 64/72] END learning_rate=0.001, max_depth=7, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 1/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 2/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 3/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 4/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 5/5; 65/72] START learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 65/72] END learning_rate=0.001, max_depth=7, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 1/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 2/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 3/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 4/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 5/5; 66/72] START learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 66/72] END learning_rate=0.001, max_depth=7, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 1/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 2/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 3/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 4/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 5/5; 67/72] START learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 67/72] END learning_rate=0.001, max_depth=8, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 1/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 2/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 3/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 4/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 5/5; 68/72] START learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 68/72] END learning_rate=0.001, max_depth=8, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 1/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 2/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 3/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 4/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 5/5; 69/72] START learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 69/72] END learning_rate=0.001, max_depth=8, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.1s
# [CV 1/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 1/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 2/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 2/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 3/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 3/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 4/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 4/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 5/5; 70/72] START learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0
# [CV 5/5; 70/72] END learning_rate=0.001, max_depth=9, n_estimators=50, objective=reg:squarederror, random_state=0; total time=   1.0s
# [CV 1/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 1/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 2/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 2/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 3/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 3/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 4/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 4/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.1s
# [CV 5/5; 71/72] START learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0
# [CV 5/5; 71/72] END learning_rate=0.001, max_depth=9, n_estimators=100, objective=reg:squarederror, random_state=0; total time=   2.0s
# [CV 1/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 1/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 2/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 2/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 3/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 3/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# [CV 4/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 4/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   3.0s
# [CV 5/5; 72/72] START learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0
# [CV 5/5; 72/72] END learning_rate=0.001, max_depth=9, n_estimators=150, objective=reg:squarederror, random_state=0; total time=   2.9s
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, mon...
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                          'n_estimators': [50, 100, 150],
#                          'objective': ['reg:squarederror'],
#                          'random_state': [0]},
#              return_train_score=True, verbose=100)

# %%
print(reg_cv_xgb.best_params_)
y_pred = reg_cv_xgb.predict(X_val)
y_pred
# Out:
# {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 150, 'objective': 'reg:squarederror', 'random_state': 0}
# array([105.31502 , 105.29208 , 105.273994, ..., 109.32139 , 109.32423 ,
#        109.28726 ], dtype=float32)

# %%
import pickle

filename='model_sell.pkl'
pickle.dump(reg_cv_xgb.best_estimator_, open(filename, 'wb'))

# %%
y_ = np.concatenate([np.array([None for i in range(len(y_train))]) , y_pred])
y_ = pd.DataFrame(y_, index=X.index)

plt.figure(figsize=(16,5))
plt.plot(y, label='original')
plt.plot(y_, '--', label='predict')
plt.legend()
plt.show()

plt.figure(figsize=(16,5))
plt.plot(y[-50:], label='original')
plt.plot(y_[-50:], '--', label='predict')
plt.legend()
plt.show()
