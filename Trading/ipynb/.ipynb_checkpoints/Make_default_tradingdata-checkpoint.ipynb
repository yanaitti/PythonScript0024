# %%
import pandas as pd
import datetime

# %%
# !dir inputs
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is F6A2-5568
#
#  Directory of D:\PythonTraining\Trading\other_fx\ipynb\inputs
#
# 2021/05/04  21:14    <DIR>          .
# 2021/05/04  21:14    <DIR>          ..
# 2021/05/04  21:14                48 .gitignore
# 2021/05/02  12:30           677,304 NI225_M15.csv
# 2021/05/02  12:30                87 NI225_M15.csv.dvc
# 2021/05/04  21:35         4,900,839 USDJPY15.csv
# 2021/05/04  21:14                86 USDJPY15.csv.dvc
# 2021/05/05  16:47         1,663,253 USDJPY_M15.csv
# 2021/05/04  17:24                89 USDJPY_M15.csv.dvc
#                7 File(s)      7,241,706 bytes
#                2 Dir(s)  461,129,666,560 bytes free

# %%
data = pd.read_csv('inputs/USDJPY_M15.csv', sep='\t', names=('date', 'time', 'open', 'high', 'low', 'close'), usecols=[0, 1, 2, 3, 4, 5], skiprows=1)
# data = pd.read_csv('inputs/USDJPY15.csv', names=('date', 'time', 'open', 'high', 'low', 'close'), usecols=[0, 1, 2, 3, 4, 5], skiprows=1)
data['datetime'] = pd.to_datetime(data['date']  + ' ' + data['time'])
data.drop(['date', 'time'], axis=1, inplace=True)
data['time'] = data['datetime'].apply(lambda x: int(x.timestamp()))
data.drop(['datetime'], axis=1, inplace=True)
data['currency'] = 'USDJPY'
data['period'] = '15'
data['id'] = ''
data = data[:-1]
data
# Out:
#           open     high      low    close        time currency period id
# 0      107.525  107.552  107.470  107.537  1585699200   USDJPY     15
# 1      107.537  107.555  107.514  107.540  1585700100   USDJPY     15
# 2      107.540  107.563  107.523  107.523  1585701000   USDJPY     15
# 3      107.523  107.527  107.509  107.509  1585701900   USDJPY     15
# 4      107.509  107.551  107.480  107.551  1585702800   USDJPY     15
# ...        ...      ...      ...      ...         ...      ...    ... ..
# 27205  109.437  109.479  109.428  109.431  1620207000   USDJPY     15
# 27206  109.432  109.475  109.401  109.426  1620207900   USDJPY     15
# 27207  109.427  109.445  109.391  109.431  1620208800   USDJPY     15
# 27208  109.432  109.438  109.388  109.420  1620209700   USDJPY     15
# 27209  109.419  109.462  109.418  109.444  1620210600   USDJPY     15
#
# [27210 rows x 8 columns]

# %%
data[['currency', 'period', 'time', 'open', 'high', 'low', 'close']][-1000:].reset_index(drop=True)
# Out:
#     currency period        time     open     high      low    close
# 0     USDJPY     15  1618965900  108.056  108.067  108.049  108.063
# 1     USDJPY     15  1618966800  108.063  108.089  108.062  108.081
# 2     USDJPY     15  1618967700  108.082  108.102  108.080  108.099
# 3     USDJPY     15  1618968600  108.101  108.123  108.094  108.121
# 4     USDJPY     15  1618969500  108.121  108.123  108.104  108.108
# ..       ...    ...         ...      ...      ...      ...      ...
# 995   USDJPY     15  1620207000  109.437  109.479  109.428  109.431
# 996   USDJPY     15  1620207900  109.432  109.475  109.401  109.426
# 997   USDJPY     15  1620208800  109.427  109.445  109.391  109.431
# 998   USDJPY     15  1620209700  109.432  109.438  109.388  109.420
# 999   USDJPY     15  1620210600  109.419  109.462  109.418  109.444
#
# [1000 rows x 7 columns]

# %%
data[['currency', 'period', 'time', 'open', 'high', 'low', 'close']][-1000:].reset_index(drop=True).to_csv('data.csv')
