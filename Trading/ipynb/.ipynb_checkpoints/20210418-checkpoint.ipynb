# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import datetime

# %%
# !dir inputs
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is F6A2-5568
#
#  Directory of D:\PythonTraining\Trading\other_fx\inputs
#
# 2021/04/18  15:32    <DIR>          .
# 2021/04/18  15:32    <DIR>          ..
# 2021/04/18  15:21         5,123,971 EURGBP_M5_202003020000_202104162350.csv
# 2021/04/18  15:22         5,132,419 EURJPY_M5_202003020000_202104162350.csv
# 2021/04/18  15:20         5,118,719 EURUSD_M5_202003020000_202104162350.csv
# 2021/04/18  15:22         5,153,576 GBPJPY_M5_202003020000_202104162350.csv
# 2021/04/18  15:20         5,133,619 GBPUSD_M5_202003020000_202104162350.csv
# 2021/04/18  15:32    <DIR>          m1
# 2021/04/18  15:21         5,117,348 USDJPY_M5_202003020000_202104162350.csv
#                6 File(s)     30,779,652 bytes
#                3 Dir(s)  466,197,475,328 bytes free

# %%
import pathlib

# y = {}
all_datasets = []

p_temp = pathlib.Path('inputs').glob('*.csv')
for p in p_temp:
    dataset = pd.DataFrame()
    
    curr = p.name.split('_')[0]
    tmp = pd.read_csv('inputs/' + p.name, sep='\t')
    dataset['<DATETIME>'] = tmp['<DATE>'] + ' ' + tmp['<TIME>']
#     y[curr] = tmp['<CLOSE>']
    dataset['<CLOSE>'] = tmp['<CLOSE>']
    
    for i in range(1, 13):
        dataset['shift%s'%i] = tmp['<CLOSE>'].shift(i)
    
#     dataset.drop(['<SPREAD>'], axis=1, inplace=True)
#     datasets[curr] = dataset

    # Calculate Simple Moving Average
#     dataset['<20SMA>'] = dataset['shift1'].rolling(20).mean().fillna(0)
#     dataset['<50SMA>'] = dataset['shift1'].rolling(50).mean().fillna(0)
#     dataset['<100SMA>'] = dataset['shift1'].rolling(100).mean().fillna(0)
    
    # Calculate diff of 5min ago
    dataset['<5DIFF>'] = abs(dataset['shift1'] - dataset['shift1'].shift(5).fillna(0))
#     dataset['<5DIFF>'] = dataset['<CLOSE>'].shift(5).fillna(0)
    
    if len(all_datasets) == 0:
        all_datasets = dataset
    else:
#         all_datasets = pd.merge(all_datasets, datasets[curr], on='<DATETIME>', suffixes=['', '_' + curr], how='outer')
#         dataset.drop(['<DATE>', '<TIME>'], axis=1, inplace=True)
        all_datasets = pd.merge(all_datasets, dataset, on='<DATETIME>', suffixes=['', '_' + curr])
    
print(all_datasets)
# Out:
#                 <DATETIME>  <CLOSE>   shift1   shift2   shift3   shift4  \
# 0      2020.03.02 00:00:00  0.86187      NaN      NaN      NaN      NaN
# 1      2020.03.02 00:05:00  0.86243  0.86187      NaN      NaN      NaN
# 2      2020.03.02 00:10:00  0.86139  0.86243  0.86187      NaN      NaN
# 3      2020.03.02 00:15:00  0.86194  0.86139  0.86243  0.86187      NaN
# 4      2020.03.02 00:20:00  0.86098  0.86194  0.86139  0.86243  0.86187
# ...                    ...      ...      ...      ...      ...      ...
# 84169  2021.04.16 23:30:00  0.86563  0.86569  0.86571  0.86575  0.86576
# 84170  2021.04.16 23:35:00  0.86569  0.86563  0.86569  0.86571  0.86575
# 84171  2021.04.16 23:40:00  0.86578  0.86569  0.86563  0.86569  0.86571
# 84172  2021.04.16 23:45:00  0.86569  0.86578  0.86569  0.86563  0.86569
# 84173  2021.04.16 23:50:00  0.86556  0.86569  0.86578  0.86569  0.86563
#
#         shift5   shift6   shift7   shift8  ...  shift7_USDJPY  shift8_USDJPY  \
# 0          NaN      NaN      NaN      NaN  ...            NaN            NaN
# 1          NaN      NaN      NaN      NaN  ...            NaN            NaN
# 2          NaN      NaN      NaN      NaN  ...            NaN            NaN
# 3          NaN      NaN      NaN      NaN  ...            NaN            NaN
# 4          NaN      NaN      NaN      NaN  ...            NaN            NaN
# ...        ...      ...      ...      ...  ...            ...            ...
# 84169  0.86570  0.86580  0.86575  0.86576  ...        108.793        108.798
# 84170  0.86576  0.86570  0.86580  0.86575  ...        108.780        108.793
# 84171  0.86575  0.86576  0.86570  0.86580  ...        108.787        108.780
# 84172  0.86571  0.86575  0.86576  0.86570  ...        108.788        108.787
# 84173  0.86569  0.86571  0.86575  0.86576  ...        108.784        108.788
#
#        shift9_USDJPY  shift10_USDJPY  shift11_USDJPY  shift12_USDJPY  \
# 0                NaN             NaN             NaN             NaN
# 1                NaN             NaN             NaN             NaN
# 2                NaN             NaN             NaN             NaN
# 3                NaN             NaN             NaN             NaN
# 4                NaN             NaN             NaN             NaN
# ...              ...             ...             ...             ...
# 84169        108.788         108.793         108.793         108.788
# 84170        108.798         108.788         108.793         108.793
# 84171        108.793         108.798         108.788         108.793
# 84172        108.780         108.793         108.798         108.788
# 84173        108.787         108.780         108.793         108.798
#
#        <20SMA>_USDJPY  <50SMA>_USDJPY  <100SMA>_USDJPY  <5DIFF>_USDJPY
# 0             0.00000         0.00000          0.00000             NaN
# 1             0.00000         0.00000          0.00000         107.617
# 2             0.00000         0.00000          0.00000         107.664
# 3             0.00000         0.00000          0.00000         107.646
# 4             0.00000         0.00000          0.00000         107.704
# ...               ...             ...              ...             ...
# 84169       108.78710       108.78762        108.80554           0.017
# 84170       108.78750       108.78754        108.80572           0.005
# 84171       108.78765       108.78720        108.80555           0.008
# 84172       108.78880       108.78694        108.80521           0.011
# 84173       108.78940       108.78658        108.80481           0.014
#
# [84174 rows x 103 columns]

# %%
all_datasets.columns.tolist()
# Out:
# ['<DATETIME>',
#  '<CLOSE>',
#  'shift1',
#  'shift2',
#  'shift3',
#  'shift4',
#  'shift5',
#  'shift6',
#  'shift7',
#  'shift8',
#  'shift9',
#  'shift10',
#  'shift11',
#  'shift12',
#  '<20SMA>',
#  '<50SMA>',
#  '<100SMA>',
#  '<5DIFF>',
#  '<CLOSE>_EURJPY',
#  'shift1_EURJPY',
#  'shift2_EURJPY',
#  'shift3_EURJPY',
#  'shift4_EURJPY',
#  'shift5_EURJPY',
#  'shift6_EURJPY',
#  'shift7_EURJPY',
#  'shift8_EURJPY',
#  'shift9_EURJPY',
#  'shift10_EURJPY',
#  'shift11_EURJPY',
#  'shift12_EURJPY',
#  '<20SMA>_EURJPY',
#  '<50SMA>_EURJPY',
#  '<100SMA>_EURJPY',
#  '<5DIFF>_EURJPY',
#  '<CLOSE>_EURUSD',
#  'shift1_EURUSD',
#  'shift2_EURUSD',
#  'shift3_EURUSD',
#  'shift4_EURUSD',
#  'shift5_EURUSD',
#  'shift6_EURUSD',
#  'shift7_EURUSD',
#  'shift8_EURUSD',
#  'shift9_EURUSD',
#  'shift10_EURUSD',
#  'shift11_EURUSD',
#  'shift12_EURUSD',
#  '<20SMA>_EURUSD',
#  '<50SMA>_EURUSD',
#  '<100SMA>_EURUSD',
#  '<5DIFF>_EURUSD',
#  '<CLOSE>_GBPJPY',
#  'shift1_GBPJPY',
#  'shift2_GBPJPY',
#  'shift3_GBPJPY',
#  'shift4_GBPJPY',
#  'shift5_GBPJPY',
#  'shift6_GBPJPY',
#  'shift7_GBPJPY',
#  'shift8_GBPJPY',
#  'shift9_GBPJPY',
#  'shift10_GBPJPY',
#  'shift11_GBPJPY',
#  'shift12_GBPJPY',
#  '<20SMA>_GBPJPY',
#  '<50SMA>_GBPJPY',
#  '<100SMA>_GBPJPY',
#  '<5DIFF>_GBPJPY',
#  '<CLOSE>_GBPUSD',
#  'shift1_GBPUSD',
#  'shift2_GBPUSD',
#  'shift3_GBPUSD',
#  'shift4_GBPUSD',
#  'shift5_GBPUSD',
#  'shift6_GBPUSD',
#  'shift7_GBPUSD',
#  'shift8_GBPUSD',
#  'shift9_GBPUSD',
#  'shift10_GBPUSD',
#  'shift11_GBPUSD',
#  'shift12_GBPUSD',
#  '<20SMA>_GBPUSD',
#  '<50SMA>_GBPUSD',
#  '<100SMA>_GBPUSD',
#  '<5DIFF>_GBPUSD',
#  '<CLOSE>_USDJPY',
#  'shift1_USDJPY',
#  'shift2_USDJPY',
#  'shift3_USDJPY',
#  'shift4_USDJPY',
#  'shift5_USDJPY',
#  'shift6_USDJPY',
#  'shift7_USDJPY',
#  'shift8_USDJPY',
#  'shift9_USDJPY',
#  'shift10_USDJPY',
#  'shift11_USDJPY',
#  'shift12_USDJPY',
#  '<20SMA>_USDJPY',
#  '<50SMA>_USDJPY',
#  '<100SMA>_USDJPY',
#  '<5DIFF>_USDJPY']

# %%
all_datasets
# Out:
#                 <DATETIME>  <CLOSE>   shift1   shift2   shift3   shift4  \
# 0      2020.03.02 00:00:00  0.86187      NaN      NaN      NaN      NaN
# 1      2020.03.02 00:05:00  0.86243  0.86187      NaN      NaN      NaN
# 2      2020.03.02 00:10:00  0.86139  0.86243  0.86187      NaN      NaN
# 3      2020.03.02 00:15:00  0.86194  0.86139  0.86243  0.86187      NaN
# 4      2020.03.02 00:20:00  0.86098  0.86194  0.86139  0.86243  0.86187
# ...                    ...      ...      ...      ...      ...      ...
# 84169  2021.04.16 23:30:00  0.86563  0.86569  0.86571  0.86575  0.86576
# 84170  2021.04.16 23:35:00  0.86569  0.86563  0.86569  0.86571  0.86575
# 84171  2021.04.16 23:40:00  0.86578  0.86569  0.86563  0.86569  0.86571
# 84172  2021.04.16 23:45:00  0.86569  0.86578  0.86569  0.86563  0.86569
# 84173  2021.04.16 23:50:00  0.86556  0.86569  0.86578  0.86569  0.86563
#
#         shift5   shift6   shift7   shift8  ...  shift7_USDJPY  shift8_USDJPY  \
# 0          NaN      NaN      NaN      NaN  ...            NaN            NaN
# 1          NaN      NaN      NaN      NaN  ...            NaN            NaN
# 2          NaN      NaN      NaN      NaN  ...            NaN            NaN
# 3          NaN      NaN      NaN      NaN  ...            NaN            NaN
# 4          NaN      NaN      NaN      NaN  ...            NaN            NaN
# ...        ...      ...      ...      ...  ...            ...            ...
# 84169  0.86570  0.86580  0.86575  0.86576  ...        108.793        108.798
# 84170  0.86576  0.86570  0.86580  0.86575  ...        108.780        108.793
# 84171  0.86575  0.86576  0.86570  0.86580  ...        108.787        108.780
# 84172  0.86571  0.86575  0.86576  0.86570  ...        108.788        108.787
# 84173  0.86569  0.86571  0.86575  0.86576  ...        108.784        108.788
#
#        shift9_USDJPY  shift10_USDJPY  shift11_USDJPY  shift12_USDJPY  \
# 0                NaN             NaN             NaN             NaN
# 1                NaN             NaN             NaN             NaN
# 2                NaN             NaN             NaN             NaN
# 3                NaN             NaN             NaN             NaN
# 4                NaN             NaN             NaN             NaN
# ...              ...             ...             ...             ...
# 84169        108.788         108.793         108.793         108.788
# 84170        108.798         108.788         108.793         108.793
# 84171        108.793         108.798         108.788         108.793
# 84172        108.780         108.793         108.798         108.788
# 84173        108.787         108.780         108.793         108.798
#
#        <20SMA>_USDJPY  <50SMA>_USDJPY  <100SMA>_USDJPY  <5DIFF>_USDJPY
# 0             0.00000         0.00000          0.00000             NaN
# 1             0.00000         0.00000          0.00000         107.617
# 2             0.00000         0.00000          0.00000         107.664
# 3             0.00000         0.00000          0.00000         107.646
# 4             0.00000         0.00000          0.00000         107.704
# ...               ...             ...              ...             ...
# 84169       108.78710       108.78762        108.80554           0.017
# 84170       108.78750       108.78754        108.80572           0.005
# 84171       108.78765       108.78720        108.80555           0.008
# 84172       108.78880       108.78694        108.80521           0.011
# 84173       108.78940       108.78658        108.80481           0.014
#
# [84174 rows x 103 columns]

# %%
all_datasets.describe()
# Out:
#             <CLOSE>        shift1        shift2        shift3        shift4  \
# count  84174.000000  84173.000000  84172.000000  84171.000000  84170.000000
# mean       0.891272      0.891272      0.891273      0.891273      0.891273
# std        0.018066      0.018066      0.018066      0.018066      0.018066
# min        0.847220      0.847220      0.847220      0.847220      0.847220
# 25%        0.876380      0.876380      0.876388      0.876390      0.876390
# 50%        0.895480      0.895480      0.895480      0.895480      0.895480
# 75%        0.904510      0.904510      0.904510      0.904510      0.904510
# max        0.949160      0.949160      0.949160      0.949160      0.949160
#
#              shift5        shift6        shift7        shift8        shift9  \
# count  84169.000000  84168.000000  84167.000000  84166.000000  84165.000000
# mean       0.891274      0.891274      0.891274      0.891274      0.891275
# std        0.018066      0.018066      0.018065      0.018065      0.018065
# min        0.847220      0.847220      0.847220      0.847220      0.847220
# 25%        0.876390      0.876390      0.876390      0.876390      0.876390
# 50%        0.895480      0.895480      0.895480      0.895480      0.895480
# 75%        0.904510      0.904510      0.904510      0.904510      0.904510
# max        0.949160      0.949160      0.949160      0.949160      0.949160
#
#        ...  shift7_USDJPY  shift8_USDJPY  shift9_USDJPY  shift10_USDJPY  \
# count  ...   84167.000000   84166.000000   84165.000000    84164.000000
# mean   ...     106.307115     106.307086     106.307056      106.307028
# std    ...       1.885906       1.885898       1.885890        1.885883
# min    ...     101.344000     101.344000     101.344000      101.344000
# 25%    ...     104.773000     104.773000     104.773000      104.773000
# 50%    ...     106.137000     106.137000     106.137000      106.137000
# 75%    ...     107.555000     107.555000     107.555000      107.555000
# max    ...     111.667000     111.667000     111.667000      111.667000
#
#        shift11_USDJPY  shift12_USDJPY  <20SMA>_USDJPY  <50SMA>_USDJPY  \
# count    84163.000000    84162.000000    84174.000000    84174.000000
# mean       106.307000      106.306970      106.281605      106.243031
# std          1.885875        1.885866        2.497458        3.202435
# min        101.344000      101.344000        0.000000        0.000000
# 25%        104.773000      104.773000      104.768162      104.755805
# 50%        106.137000      106.137000      106.131750      106.131470
# 75%        107.555000      107.555000      107.555612      107.553335
# max        111.667000      111.667000      111.553900      111.512240
#
#        <100SMA>_USDJPY  <5DIFF>_USDJPY
# count     84174.000000    84173.000000
# mean        106.178655        0.048194
# std           4.116537        0.831342
# min           0.000000        0.000000
# 25%         104.752635        0.012000
# 50%         106.133335        0.027000
# 75%         107.559095        0.052000
# max         111.408450      107.734000
#
# [8 rows x 102 columns]

# %%
all_datasets.isnull().any()
# Out:
# <DATETIME>         False
# <CLOSE>            False
# shift1              True
# shift2              True
# shift3              True
#                    ...
# shift12_USDJPY      True
# <20SMA>_USDJPY     False
# <50SMA>_USDJPY     False
# <100SMA>_USDJPY    False
# <5DIFF>_USDJPY      True
# Length: 103, dtype: bool

# %%
all_datasets2 = all_datasets.iloc[100:]
all_datasets2
# Out:
#                 <DATETIME>  <CLOSE>   shift1   shift2   shift3   shift4  \
# 100    2020.03.02 08:20:00  0.86012  0.86056  0.86067  0.86069  0.86058
# 101    2020.03.02 08:25:00  0.85944  0.86012  0.86056  0.86067  0.86069
# 102    2020.03.02 08:30:00  0.85996  0.85944  0.86012  0.86056  0.86067
# 103    2020.03.02 08:35:00  0.85979  0.85996  0.85944  0.86012  0.86056
# 104    2020.03.02 08:40:00  0.85978  0.85979  0.85996  0.85944  0.86012
# ...                    ...      ...      ...      ...      ...      ...
# 84169  2021.04.16 23:30:00  0.86563  0.86569  0.86571  0.86575  0.86576
# 84170  2021.04.16 23:35:00  0.86569  0.86563  0.86569  0.86571  0.86575
# 84171  2021.04.16 23:40:00  0.86578  0.86569  0.86563  0.86569  0.86571
# 84172  2021.04.16 23:45:00  0.86569  0.86578  0.86569  0.86563  0.86569
# 84173  2021.04.16 23:50:00  0.86556  0.86569  0.86578  0.86569  0.86563
#
#         shift5   shift6   shift7   shift8  ...  shift7_USDJPY  shift8_USDJPY  \
# 100    0.86092  0.86082  0.86095  0.86066  ...        108.159        108.138
# 101    0.86058  0.86092  0.86082  0.86095  ...        108.221        108.159
# 102    0.86069  0.86058  0.86092  0.86082  ...        108.263        108.221
# 103    0.86067  0.86069  0.86058  0.86092  ...        108.254        108.263
# 104    0.86056  0.86067  0.86069  0.86058  ...        108.278        108.254
# ...        ...      ...      ...      ...  ...            ...            ...
# 84169  0.86570  0.86580  0.86575  0.86576  ...        108.793        108.798
# 84170  0.86576  0.86570  0.86580  0.86575  ...        108.780        108.793
# 84171  0.86575  0.86576  0.86570  0.86580  ...        108.787        108.780
# 84172  0.86571  0.86575  0.86576  0.86570  ...        108.788        108.787
# 84173  0.86569  0.86571  0.86575  0.86576  ...        108.784        108.788
#
#        shift9_USDJPY  shift10_USDJPY  shift11_USDJPY  shift12_USDJPY  \
# 100          108.112         108.145         108.161         108.125
# 101          108.138         108.112         108.145         108.161
# 102          108.159         108.138         108.112         108.145
# 103          108.221         108.159         108.138         108.112
# 104          108.263         108.221         108.159         108.138
# ...              ...             ...             ...             ...
# 84169        108.788         108.793         108.793         108.788
# 84170        108.798         108.788         108.793         108.793
# 84171        108.793         108.798         108.788         108.793
# 84172        108.780         108.793         108.798         108.788
# 84173        108.787         108.780         108.793         108.798
#
#        <20SMA>_USDJPY  <50SMA>_USDJPY  <100SMA>_USDJPY  <5DIFF>_USDJPY
# 100         108.16100       108.17138        107.93780           0.003
# 101         108.16895       108.17656        107.94391           0.035
# 102         108.17635       108.18122        107.94987           0.006
# 103         108.18040       108.18584        107.95588           0.031
# 104         108.18680       108.19078        107.96137           0.012
# ...               ...             ...              ...             ...
# 84169       108.78710       108.78762        108.80554           0.017
# 84170       108.78750       108.78754        108.80572           0.005
# 84171       108.78765       108.78720        108.80555           0.008
# 84172       108.78880       108.78694        108.80521           0.011
# 84173       108.78940       108.78658        108.80481           0.014
#
# [84074 rows x 103 columns]

# %%
all_datasets2.isnull().sum()
# Out:
# <DATETIME>         0
# <CLOSE>            0
# shift1             0
# shift2             0
# shift3             0
#                   ..
# shift12_USDJPY     0
# <20SMA>_USDJPY     0
# <50SMA>_USDJPY     0
# <100SMA>_USDJPY    0
# <5DIFF>_USDJPY     0
# Length: 103, dtype: int64

# %% [markdown]
# # Make Predict model by LightGBM

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, train_test_split

# %%
y = all_datasets2['<CLOSE>']
X = all_datasets2.drop(['<DATETIME>', '<CLOSE>', '<CLOSE>_EURJPY', '<CLOSE>_EURUSD', '<CLOSE>_GBPJPY', '<CLOSE>_GBPUSD', '<CLOSE>_USDJPY'], axis=1)

# %%
X.shape
# Out:
# (84074, 96)

# %%
y.shape
# Out:
# (84074,)

# %%
X.columns.tolist()
# Out:
# ['shift1',
#  'shift2',
#  'shift3',
#  'shift4',
#  'shift5',
#  'shift6',
#  'shift7',
#  'shift8',
#  'shift9',
#  'shift10',
#  'shift11',
#  'shift12',
#  '<20SMA>',
#  '<50SMA>',
#  '<100SMA>',
#  '<5DIFF>',
#  'shift1_EURJPY',
#  'shift2_EURJPY',
#  'shift3_EURJPY',
#  'shift4_EURJPY',
#  'shift5_EURJPY',
#  'shift6_EURJPY',
#  'shift7_EURJPY',
#  'shift8_EURJPY',
#  'shift9_EURJPY',
#  'shift10_EURJPY',
#  'shift11_EURJPY',
#  'shift12_EURJPY',
#  '<20SMA>_EURJPY',
#  '<50SMA>_EURJPY',
#  '<100SMA>_EURJPY',
#  '<5DIFF>_EURJPY',
#  'shift1_EURUSD',
#  'shift2_EURUSD',
#  'shift3_EURUSD',
#  'shift4_EURUSD',
#  'shift5_EURUSD',
#  'shift6_EURUSD',
#  'shift7_EURUSD',
#  'shift8_EURUSD',
#  'shift9_EURUSD',
#  'shift10_EURUSD',
#  'shift11_EURUSD',
#  'shift12_EURUSD',
#  '<20SMA>_EURUSD',
#  '<50SMA>_EURUSD',
#  '<100SMA>_EURUSD',
#  '<5DIFF>_EURUSD',
#  'shift1_GBPJPY',
#  'shift2_GBPJPY',
#  'shift3_GBPJPY',
#  'shift4_GBPJPY',
#  'shift5_GBPJPY',
#  'shift6_GBPJPY',
#  'shift7_GBPJPY',
#  'shift8_GBPJPY',
#  'shift9_GBPJPY',
#  'shift10_GBPJPY',
#  'shift11_GBPJPY',
#  'shift12_GBPJPY',
#  '<20SMA>_GBPJPY',
#  '<50SMA>_GBPJPY',
#  '<100SMA>_GBPJPY',
#  '<5DIFF>_GBPJPY',
#  'shift1_GBPUSD',
#  'shift2_GBPUSD',
#  'shift3_GBPUSD',
#  'shift4_GBPUSD',
#  'shift5_GBPUSD',
#  'shift6_GBPUSD',
#  'shift7_GBPUSD',
#  'shift8_GBPUSD',
#  'shift9_GBPUSD',
#  'shift10_GBPUSD',
#  'shift11_GBPUSD',
#  'shift12_GBPUSD',
#  '<20SMA>_GBPUSD',
#  '<50SMA>_GBPUSD',
#  '<100SMA>_GBPUSD',
#  '<5DIFF>_GBPUSD',
#  'shift1_USDJPY',
#  'shift2_USDJPY',
#  'shift3_USDJPY',
#  'shift4_USDJPY',
#  'shift5_USDJPY',
#  'shift6_USDJPY',
#  'shift7_USDJPY',
#  'shift8_USDJPY',
#  'shift9_USDJPY',
#  'shift10_USDJPY',
#  'shift11_USDJPY',
#  'shift12_USDJPY',
#  '<20SMA>_USDJPY',
#  '<50SMA>_USDJPY',
#  '<100SMA>_USDJPY',
#  '<5DIFF>_USDJPY']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_val, y_val, reference=lgb_train)

# %%
# LightGBM parameters
params = {
        'task' : 'train',
        'boosting':'gbdt',
        'objective' : 'regression',
        'metric' : {'mse'},
        'num_leaves':78,
        'drop_rate':0.05,
        'learning_rate':0.01,
        'seed':0,
        'verbose':0,
        'device': 'cpu'
}

# %%
evaluation_results = {}
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=100000,
                valid_sets=[lgb_train, lgb_eval],
                valid_names=['Train', 'Valid'],
                evals_result=evaluation_results,
                early_stopping_rounds=1000,
                verbose_eval=100)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.079463 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# Training until validation scores don't improve for 1000 rounds
# [100]	Train's l2: 2.75457e-05	Valid's l2: 9.46227e-06
# [200]	Train's l2: 3.79871e-06	Valid's l2: 1.37134e-06
# [300]	Train's l2: 6.08196e-07	Valid's l2: 2.68354e-07
# [400]	Train's l2: 1.74317e-07	Valid's l2: 1.20839e-07
# [500]	Train's l2: 1.10949e-07	Valid's l2: 1.0732e-07
# [600]	Train's l2: 9.83797e-08	Valid's l2: 1.06181e-07
# [700]	Train's l2: 9.32943e-08	Valid's l2: 1.06238e-07
# [800]	Train's l2: 8.95505e-08	Valid's l2: 1.07073e-07
# [900]	Train's l2: 8.66227e-08	Valid's l2: 1.08359e-07
# [1000]	Train's l2: 8.41341e-08	Valid's l2: 1.09369e-07
# [1100]	Train's l2: 8.18423e-08	Valid's l2: 1.12473e-07
# [1200]	Train's l2: 7.95011e-08	Valid's l2: 1.14688e-07
# [1300]	Train's l2: 7.72485e-08	Valid's l2: 1.15657e-07
# [1400]	Train's l2: 7.51081e-08	Valid's l2: 1.15699e-07
# [1500]	Train's l2: 7.31836e-08	Valid's l2: 1.17004e-07
# [1600]	Train's l2: 7.13316e-08	Valid's l2: 1.17371e-07
# Early stopping, best iteration is:
# [643]	Train's l2: 9.58896e-08	Valid's l2: 1.06067e-07

# %%
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)

# %%
y_pred
# Out:
# array([0.88831378, 0.88831378, 0.88831378, ..., 0.86571343, 0.86571343,
#        0.86571343])

# %%
y_ = np.concatenate([np.array([None for i in range(len(y_train)+len(y_val))]) , y_pred])
y_ = pd.DataFrame(y_, index=X.index)

plt.figure(figsize=(16,5))
plt.plot(y[-500:], label='original')
plt.plot(y_[-500:], '--', label='predict')
plt.legend()
