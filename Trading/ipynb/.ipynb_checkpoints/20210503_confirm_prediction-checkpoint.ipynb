# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('inputs/USDJPY_M15.csv', sep='\t', names=('date', 'time', 'open', 'high', 'low', 'close'), usecols=[0, 1, 2, 3, 4, 5], header=1)
data = data[:-1]
data['datetime'] = pd.to_datetime(data['date']  + ' ' + data['time'])
data.drop(['date', 'time'], axis=1, inplace=True)
data
# Out:
#           open     high      low    close            datetime
# 0      107.520  107.545  107.469  107.540 2020-04-01 00:15:00
# 1      107.540  107.544  107.476  107.492 2020-04-01 00:30:00
# 2      107.492  107.519  107.465  107.481 2020-04-01 00:45:00
# 3      107.481  107.549  107.481  107.547 2020-04-01 01:00:00
# 4      107.549  107.549  107.514  107.532 2020-04-01 01:15:00
# ...        ...      ...      ...      ...                 ...
# 27070  109.271  109.282  109.258  109.269 2021-05-04 07:30:00
# 27071  109.269  109.287  109.257  109.283 2021-05-04 07:45:00
# 27072  109.283  109.302  109.264  109.296 2021-05-04 08:00:00
# 27073  109.295  109.353  109.289  109.347 2021-05-04 08:15:00
# 27074  109.348  109.349  109.318  109.322 2021-05-04 08:30:00
#
# [27075 rows x 5 columns]

# %%
# all_data = pd.merge(data, ni225, on='datetime', suffixes=['', '_ni225']).drop(['date_ni225', 'time_ni225'], axis=1)
all_data = data.copy()
all_data
# Out:
#           open     high      low    close            datetime
# 0      107.520  107.545  107.469  107.540 2020-04-01 00:15:00
# 1      107.540  107.544  107.476  107.492 2020-04-01 00:30:00
# 2      107.492  107.519  107.465  107.481 2020-04-01 00:45:00
# 3      107.481  107.549  107.481  107.547 2020-04-01 01:00:00
# 4      107.549  107.549  107.514  107.532 2020-04-01 01:15:00
# ...        ...      ...      ...      ...                 ...
# 27070  109.271  109.282  109.258  109.269 2021-05-04 07:30:00
# 27071  109.269  109.287  109.257  109.283 2021-05-04 07:45:00
# 27072  109.283  109.302  109.264  109.296 2021-05-04 08:00:00
# 27073  109.295  109.353  109.289  109.347 2021-05-04 08:15:00
# 27074  109.348  109.349  109.318  109.322 2021-05-04 08:30:00
#
# [27075 rows x 5 columns]

# %%
# extract features from date
all_data['day'] = [i.day for i in all_data['datetime']]
all_data['month'] = [i.month for i in all_data['datetime']]
all_data['year'] = [i.year for i in all_data['datetime']]
all_data['day_of_week'] = [i.dayofweek for i in all_data['datetime']]
all_data['day_of_year'] = [i.dayofyear for i in all_data['datetime']]

all_data['hour'] = [i.hour for i in all_data['datetime']]
all_data['minute'] = [i.minute for i in all_data['datetime']]

all_data
# Out:
#           open     high      low    close            datetime  day  month  \
# 0      107.520  107.545  107.469  107.540 2020-04-01 00:15:00    1      4
# 1      107.540  107.544  107.476  107.492 2020-04-01 00:30:00    1      4
# 2      107.492  107.519  107.465  107.481 2020-04-01 00:45:00    1      4
# 3      107.481  107.549  107.481  107.547 2020-04-01 01:00:00    1      4
# 4      107.549  107.549  107.514  107.532 2020-04-01 01:15:00    1      4
# ...        ...      ...      ...      ...                 ...  ...    ...
# 27070  109.271  109.282  109.258  109.269 2021-05-04 07:30:00    4      5
# 27071  109.269  109.287  109.257  109.283 2021-05-04 07:45:00    4      5
# 27072  109.283  109.302  109.264  109.296 2021-05-04 08:00:00    4      5
# 27073  109.295  109.353  109.289  109.347 2021-05-04 08:15:00    4      5
# 27074  109.348  109.349  109.318  109.322 2021-05-04 08:30:00    4      5
#
#        year  day_of_week  day_of_year  hour  minute
# 0      2020            2           92     0      15
# 1      2020            2           92     0      30
# 2      2020            2           92     0      45
# 3      2020            2           92     1       0
# 4      2020            2           92     1      15
# ...     ...          ...          ...   ...     ...
# 27070  2021            1          124     7      30
# 27071  2021            1          124     7      45
# 27072  2021            1          124     8       0
# 27073  2021            1          124     8      15
# 27074  2021            1          124     8      30
#
# [27075 rows x 12 columns]

# %%
# dataset = all_data[['open', 'high', 'low', 'close', 'tickvol', 'day', 'month', 'year', 'day_of_week', 'day_of_year', 'hour', 'minute', 'open_ni225', 'high_ni225', 'low_ni225', 'close_ni225', 'tickvol_ni225']]
dataset = all_data[['open', 'high', 'low', 'close', 'day', 'month', 'year', 'day_of_week', 'day_of_year', 'hour', 'minute']]
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 0      107.520  107.545  107.469  107.540    1      4  2020            2
# 1      107.540  107.544  107.476  107.492    1      4  2020            2
# 2      107.492  107.519  107.465  107.481    1      4  2020            2
# 3      107.481  107.549  107.481  107.547    1      4  2020            2
# 4      107.549  107.549  107.514  107.532    1      4  2020            2
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 27070  109.271  109.282  109.258  109.269    4      5  2021            1
# 27071  109.269  109.287  109.257  109.283    4      5  2021            1
# 27072  109.283  109.302  109.264  109.296    4      5  2021            1
# 27073  109.295  109.353  109.289  109.347    4      5  2021            1
# 27074  109.348  109.349  109.318  109.322    4      5  2021            1
#
#        day_of_year  hour  minute
# 0               92     0      15
# 1               92     0      30
# 2               92     0      45
# 3               92     1       0
# 4               92     1      15
# ...            ...   ...     ...
# 27070          124     7      30
# 27071          124     7      45
# 27072          124     8       0
# 27073          124     8      15
# 27074          124     8      30
#
# [27075 rows x 11 columns]

# %%
dataset['y'] = dataset['high'].shift(-1)
dataset[['y', 'high']]
# Out:
#              y     high
# 0      107.544  107.545
# 1      107.519  107.544
# 2      107.549  107.519
# 3      107.549  107.549
# 4      107.682  107.549
# ...        ...      ...
# 27070  109.287  109.282
# 27071  109.302  109.287
# 27072  109.353  109.302
# 27073  109.349  109.353
# 27074      NaN  109.349
#
# [27075 rows x 2 columns]

# %%
for i in range(1, 13):
    dataset['shift%s'%i] = dataset['open'].shift(i)

dataset['sma5'] = dataset['open'].rolling(5).mean()
dataset['sma15'] = dataset['open'].rolling(15).mean()
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 0      107.520  107.545  107.469  107.540    1      4  2020            2
# 1      107.540  107.544  107.476  107.492    1      4  2020            2
# 2      107.492  107.519  107.465  107.481    1      4  2020            2
# 3      107.481  107.549  107.481  107.547    1      4  2020            2
# 4      107.549  107.549  107.514  107.532    1      4  2020            2
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 27070  109.271  109.282  109.258  109.269    4      5  2021            1
# 27071  109.269  109.287  109.257  109.283    4      5  2021            1
# 27072  109.283  109.302  109.264  109.296    4      5  2021            1
# 27073  109.295  109.353  109.289  109.347    4      5  2021            1
# 27074  109.348  109.349  109.318  109.322    4      5  2021            1
#
#        day_of_year  hour  ...   shift5   shift6   shift7   shift8   shift9  \
# 0               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 1               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 2               92     0  ...      NaN      NaN      NaN      NaN      NaN
# 3               92     1  ...      NaN      NaN      NaN      NaN      NaN
# 4               92     1  ...      NaN      NaN      NaN      NaN      NaN
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 27070          124     7  ...  109.246  109.226  109.235  109.242  109.253
# 27071          124     7  ...  109.246  109.246  109.226  109.235  109.242
# 27072          124     8  ...  109.237  109.246  109.246  109.226  109.235
# 27073          124     8  ...  109.256  109.237  109.246  109.246  109.226
# 27074          124     8  ...  109.271  109.256  109.237  109.246  109.246
#
#        shift10  shift11  shift12      sma5       sma15
# 0          NaN      NaN      NaN       NaN         NaN
# 1          NaN      NaN      NaN       NaN         NaN
# 2          NaN      NaN      NaN       NaN         NaN
# 3          NaN      NaN      NaN       NaN         NaN
# 4          NaN      NaN      NaN  107.5164         NaN
# ...        ...      ...      ...       ...         ...
# 27070  109.226  109.202  109.155  109.2562  109.220067
# 27071  109.253  109.226  109.202  109.2608  109.231067
# 27072  109.242  109.253  109.226  109.2700  109.241200
# 27073  109.235  109.242  109.253  109.2778  109.250533
# 27074  109.226  109.235  109.242  109.2932  109.260267
#
# [27075 rows x 26 columns]

# %% [markdown]
# https://colab.research.google.com/drive/1zChMV6D-BrLVTQWgKxlchP2BcPDViBVx#scrollTo=1uIqDdzT-DV5&uniqifier=1

# %%
dataset = dataset[100:-1]
dataset
# Out:
#           open     high      low    close  day  month  year  day_of_week  \
# 100    107.145  107.199  107.117  107.122    2      4  2020            3
# 101    107.122  107.154  107.074  107.150    2      4  2020            3
# 102    107.149  107.227  107.148  107.200    2      4  2020            3
# 103    107.200  107.258  107.185  107.215    2      4  2020            3
# 104    107.214  107.278  107.207  107.260    2      4  2020            3
# ...        ...      ...      ...      ...  ...    ...   ...          ...
# 27069  109.271  109.285  109.264  109.271    4      5  2021            1
# 27070  109.271  109.282  109.258  109.269    4      5  2021            1
# 27071  109.269  109.287  109.257  109.283    4      5  2021            1
# 27072  109.283  109.302  109.264  109.296    4      5  2021            1
# 27073  109.295  109.353  109.289  109.347    4      5  2021            1
#
#        day_of_year  hour  ...   shift5   shift6   shift7   shift8   shift9  \
# 100             93     1  ...  107.150  107.167  107.132  107.057  107.130
# 101             93     1  ...  107.131  107.150  107.167  107.132  107.057
# 102             93     1  ...  107.041  107.131  107.150  107.167  107.132
# 103             93     2  ...  107.054  107.041  107.131  107.150  107.167
# 104             93     2  ...  107.104  107.054  107.041  107.131  107.150
# ...            ...   ...  ...      ...      ...      ...      ...      ...
# 27069          124     7  ...  109.226  109.235  109.242  109.253  109.226
# 27070          124     7  ...  109.246  109.226  109.235  109.242  109.253
# 27071          124     7  ...  109.246  109.246  109.226  109.235  109.242
# 27072          124     8  ...  109.237  109.246  109.246  109.226  109.235
# 27073          124     8  ...  109.256  109.237  109.246  109.246  109.226
#
#        shift10  shift11  shift12      sma5       sma15
# 100    106.960  107.050  107.094  107.0950  107.105733
# 101    107.130  106.960  107.050  107.0932  107.104400
# 102    107.057  107.130  106.960  107.1148  107.099067
# 103    107.132  107.057  107.130  107.1440  107.106133
# 104    107.167  107.132  107.057  107.1660  107.117067
# ...        ...      ...      ...       ...         ...
# 27069  109.202  109.155  109.131  109.2512  109.209267
# 27070  109.226  109.202  109.155  109.2562  109.220067
# 27071  109.253  109.226  109.202  109.2608  109.231067
# 27072  109.242  109.253  109.226  109.2700  109.241200
# 27073  109.235  109.242  109.253  109.2778  109.250533
#
# [26974 rows x 26 columns]

# %%
dataset[['y', 'high']]
# Out:
#              y     high
# 100    107.154  107.199
# 101    107.227  107.154
# 102    107.258  107.227
# 103    107.278  107.258
# 104    107.272  107.278
# ...        ...      ...
# 27069  109.282  109.285
# 27070  109.287  109.282
# 27071  109.302  109.287
# 27072  109.353  109.302
# 27073  109.349  109.353
#
# [26974 rows x 2 columns]

# %%
dataset.isnull().any()
# Out:
# open           False
# high           False
# low            False
# close          False
# day            False
# month          False
# year           False
# day_of_week    False
# day_of_year    False
# hour           False
# minute         False
# y              False
# shift1         False
# shift2         False
# shift3         False
# shift4         False
# shift5         False
# shift6         False
# shift7         False
# shift8         False
# shift9         False
# shift10        False
# shift11        False
# shift12        False
# sma5           False
# sma15          False
# dtype: bool

# %%
X = dataset.drop(['y'], axis=1)
y = dataset['y']

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, train_test_split

# %%
import pickle

model = pickle.load(open('model.pkl','rb'))

# %%
y_pred = model.predict(X)
y_pred
# Out:
# array([107.1964  , 107.192375, 107.26616 , ..., 109.34522 , 109.345406,
#        109.37802 ], dtype=float32)

# %%
# y_ = np.concatenate([np.array([None for i in range(len(y_train)+len(y_val))]) , y_pred])
# y_ = pd.DataFrame(y_, index=X.index)

# y = y.reset_index(drop=True)

plt.figure(figsize=(16,5))
plt.plot(y[-200:], label='original')
plt.plot(y_pred[-200:], '--', label='predict')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a9a2446924ac> in <module>
#       2 # y_ = pd.DataFrame(y_, index=X.index)
#       3
# ----> 4 y_val = y_val.reset_index(drop=True)
#       5
#       6 plt.figure(figsize=(16,5))
#
# NameError: name 'y_val' is not defined

# %%
y_pred.shape, y_val.shape

# %%
y_pred

# %%
y_val
